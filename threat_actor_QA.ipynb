# %% [markdown]
# # Threat Actor Knowledge RAG - ETDA Database
# This notebook is heavily inspired by the excellent research of Roberto Rodriguez (@Cyb3rWard0g) into the applicability of generative AI for threat intelligence purposes. It follows the same structure with small alterations for this specific use case.
#
# In specific, this notebook describes how to query a vector database in QA fashion using Langchain and OpenAI. It uses the vector database built with the notebook in the 'knowledge' folder. This research shows that having a large set of reports does guarantee that simple similarity search through the vector database provides the chunks that we are looking for. A minor change in the original question can result in vastly different answers. The quality of the original data will be of great influence. Because we scraped a large number of reports and did not put in a lot of effort to check their quality, this will create noise in the context the LLM has to work with.
#
# References:
#
# - https://blog.openthreatresearch.com/demystifying-generative-ai-a-security-researchers-notes/
# - https://github.com/OTRF/GenAI-Security-Adventures
# - https://github.com/OTRF/GenAI-Security-Adventures/blob/main/experiments/RAG/Threat-Intelligence/ATTCK-Groups/LangChain/notebook.ipynb
# - https://python.langchain.com/docs/get_started/introduction
# - https://apt.etda.or.th/cgi-bin/aptgroups.cgi

# %% [markdown]
# # Improvement ideas
# - [ ] Experiment with other RAG prompts
# - [ ] Expirement with other [retrieval mechanisms](https://python.langchain.com/docs/modules/data_connection/retrievers/)
# - [ ] Expirement with matching more similar vectors

# %% [markdown]
# # Import modules

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.vectorstores import Chroma
import openai
import os
from dotenv import load_dotenv
import tqdm as notebook_tqdm
from langchain import hub
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough
from langchain_core.runnables import RunnableParallel
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# # Define initial variables and OpenAI API key

# %%
load_dotenv()
# Get your key: https://platform.openai.com/account/api-keys
openai.api_key = os.getenv("OPENAI_API_KEY")
current_directory = os.path.dirname("__file__")
chroma_db = os.path.join(current_directory, "./knowledge/chroma_db")

# %% [markdown]
# # Load vector DB

# %%
import chromadb

persistent_client = chromadb.PersistentClient(path=chroma_db)

# Define embedding function
embedding_function = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

db = Chroma(
    client=persistent_client,
    collection_name="groups_collection",
    embedding_function=embedding_function,
)
db.get()
# Out:
# {'ids': ['d10a0c46-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0d2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0d86-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0dc2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0dfe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0e30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0e6c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0ea8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0eda-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0f16-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0f52-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0f84-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0fb6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a0ff2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a102e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a106a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a109c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a10d8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a110a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a113c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1178-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a11b4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a11dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1218-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1254-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1290-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a12c2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a12fe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1330-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a136c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a139e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a13da-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1416-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1448-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1484-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a14ac-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a14d4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a14f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a151a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1542-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a156a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1592-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a15ba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a15e2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a160a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1632-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a165a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1682-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a16aa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a16c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a16f0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1718-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1740-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1772-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a179a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a17b8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a17ea-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1812-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1830-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1858-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1880-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a18a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a18d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a18f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1916-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1948-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1970-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1998-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a19c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a19e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1a10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1a2e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1a56-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1a7e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1aa6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1b00-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1b28-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1b5a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1b82-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1baa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1bd2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1bfa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1c18-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1c40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1c68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1c90-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1cb8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1ce0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1d08-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1d30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1d58-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1d80-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1da8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1dd0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1df8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1e20-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1e48-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1e70-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1e98-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1ec0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1ee8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1f10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1f38-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1f56-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1f7e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1fa6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1fce-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a1ff6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a201e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2046-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a206e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2096-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a20be-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a20e6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a210e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2136-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a215e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a21a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a21d6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a21fe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2226-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a224e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2276-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a229e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a22c6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a22ee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2316-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a233e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2366-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a238e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a23c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a23e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2410-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2442-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a246a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2492-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a24c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a24ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2514-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a253c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2564-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a258c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a25be-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a25e6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a260e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2636-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a265e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2686-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a26ae-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a26e0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2708-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2726-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2758-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2780-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a27a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a27d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a27f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2820-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2848-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a288e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a28c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a28e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2910-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2938-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2960-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2988-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a29b0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a29d8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2a00-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2a28-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2a8c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2abe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2af0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2b18-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2b40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2b68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2b9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2bc2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2bf4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2c1c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2c44-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2c6c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2c94-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2cbc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2cee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2d16-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2d3e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2d66-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2d8e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2db6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2dde-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2e10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2e38-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2e60-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2e88-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2eb0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2ee2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2f0a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2f32-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2f5a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2f82-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2fd2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a2ffa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a302c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3054-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a307c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a30a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a30cc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a30f4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3126-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a314e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3176-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a319e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a31c6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a31ee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3216-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3248-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3270-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a32a2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a32ca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a32f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a331a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3342-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a336a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3392-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a33c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a33ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3414-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a343c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3464-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a348c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a34b4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a34dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a350e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3536-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a355e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3586-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a35b8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a35e0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3608-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3630-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3658-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3680-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a36d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a36f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3720-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3752-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a377a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a37a2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a37ca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a37f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a381a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3842-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a386a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a389c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a38c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a38f6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a391e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3946-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a396e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3996-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a39c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a39f0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3a18-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3a40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3a68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3a9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3ac2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3aea-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3b1c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3b44-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3b6c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3b9e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3bc6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3bee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3c16-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3c48-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3c70-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3c98-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3cc0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3cf2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3d1a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3d42-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3d6a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3d9c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3e46-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3e8c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3ebe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3efa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3f2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3f68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3f9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a3fcc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4008-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a403a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4076-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a40a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a40e4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4116-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4148-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4184-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a41b6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a41e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4224-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4256-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4292-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a42c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4300-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4332-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a436e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a43a0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a43dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a440e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a444a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a447c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a44ae-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a44ea-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a451c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4558-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a458a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a45c6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a45f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a462a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4666-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4698-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a46d4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4706-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4756-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4792-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a47c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a47f6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4832-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4864-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4896-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a48d2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4904-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4940-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4972-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a49a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a49e0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4a12-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4a4e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4a80-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4abc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4aee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4b20-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4b5c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4b8e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4bca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4bfc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4c38-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4c6a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4ca6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4cd8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4d14-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4d46-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4d78-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4db4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4de6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4e22-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4e54-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4e86-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4ec2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4efe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4f30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4f62-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4f9e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a4fd0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a500c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5052-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a508e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a50c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a50fc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a512e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a519c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a51d8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5214-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5246-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5278-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a52b4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a52e6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5322-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5354-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5390-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a53c2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a53f4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5430-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5462-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5494-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a54d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5502-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a553e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5570-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a55a2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a55de-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5610-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a564c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a567e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a56ba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a56ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a571e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a575a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a578c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a57c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a57fa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5836-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5868-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a589a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a58d6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5908-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5944-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a598a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a59c6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a59f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5a34-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5a66-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5aa2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5ad4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5b10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5b42-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5b7e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5bb0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5be2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5c1e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5c50-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5c8c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5cbe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5cfa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5d2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5d5e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5d9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5dcc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5e08-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5e3a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5e76-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5ea8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5ee4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5f16-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5f48-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5f84-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5fb6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a5ff2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6024-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6056-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6092-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a60c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6100-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6132-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6164-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a61a0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a61d2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a620e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6240-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6286-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a62c2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a62f4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6330-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6362-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a639e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a63d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6402-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a643e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6470-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a64ac-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a64de-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a651a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a654c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a657e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a65ba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a65ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6628-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a665a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a668c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a66c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a66fa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6736-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6768-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a67a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a67d6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6808-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6844-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6876-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a68a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a68e4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6916-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6952-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6984-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a69c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a69f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6a24-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6a60-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6a92-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6ace-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6b00-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6b32-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6b82-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6bb4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6bf0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6c22-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6c5e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6c90-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6cc2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6cfe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6d30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6d62-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6d9e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6dd0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6e02-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6e3e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6e70-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6ea2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6ede-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6f10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6f4c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6f7e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6fb0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a6fec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a701e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7050-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a708c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a70be-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a70f0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a712c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a715e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a719a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a71cc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a71fe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a723a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a726c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a729e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a72da-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a730c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7348-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a737a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a73ac-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a73e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a741a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7460-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a749c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a74ce-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a750a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a753c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a756e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a75aa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a75dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7618-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a764a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7686-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a76b8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a76ea-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7726-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7758-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a778a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a77c6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a77f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a782a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7866-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a78d4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a78f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7906-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a791a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a792e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7942-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7960-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7974-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7988-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a799c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a79b0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a79c4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a79e2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a79f6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a0a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a1e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a32-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a50-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a64-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a78-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7a8c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7aa0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7ad2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7af0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b04-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b18-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b5e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b72-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b86-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7b9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7bae-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7bc2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7be0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7bf4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c08-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c1c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c4e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c62-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c76-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c8a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7c9e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7cb2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7cd0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7ce4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7cf8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d0c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d20-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d34-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d52-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d66-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d7a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7d8e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7dac-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7dc0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7dd4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7de8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7dfc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e2e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e42-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e56-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e7e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7e92-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7eb0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7ec4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7ed8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7eec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f00-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f1e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f32-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f46-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f5a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f6e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7f82-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7fa0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7fb4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7fc8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7fdc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a7ff0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a800e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8022-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8036-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a804a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a805e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a807c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8090-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a80a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a80b8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a80cc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a80e0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a80fe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8112-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8126-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a813a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a814e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8162-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8176-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8194-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a81a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a81bc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a81d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a81e4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a81f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8234-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8248-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8266-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a827a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a828e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a82a2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a82b6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a82ca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a82e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a82fc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8310-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8324-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8338-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8356-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a836a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a837e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8392-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a83a6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a83ba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a83d8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a83ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8400-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8414-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8428-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8446-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a845a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a846e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8482-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8496-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a84b4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a84c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a84dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a84f0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8504-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8522-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8536-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a854a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a855e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8572-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8590-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a85a4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a85b8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a85e0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a85fe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8612-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8626-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a863a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a864e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a866c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8680-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8694-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a86a8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a86bc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a86d0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a86ee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8702-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8716-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a872a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a873e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a875c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8770-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8784-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8798-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a87ac-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a87c0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a87de-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a87f2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8806-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a881a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a882e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8842-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8860-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8874-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8888-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a889c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a88b0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a88ce-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a88e2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a88f6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a890a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a891e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8932-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8950-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8964-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a898c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a89a0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a89be-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a89d2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a89e6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a89fa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a0e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a54-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a7c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8a9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8aae-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ac2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ad6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8aea-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b08-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b1c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b30-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b44-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b58-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b6c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b80-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8b9e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8bb2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8bc6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8bda-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8bee-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c02-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c20-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c34-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c48-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c5c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c70-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8c84-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ca2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8cb6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8cca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8cde-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8cf2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d10-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d2e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d4c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d60-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d74-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8d92-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8da6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8dba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8dce-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8de2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e00-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e14-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e28-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e3c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e50-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e64-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e82-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8e96-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8eaa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ebe-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ed2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ef0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f04-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f18-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f2c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f40-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f54-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f68-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f86-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8f9a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8fae-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8fc2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8fd6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a8ff4-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9008-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a901c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9030-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9044-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9058-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9076-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a908a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a909e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a90b2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a90da-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a90f8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a910c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9120-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9134-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9148-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a915c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a917a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a918e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a91a2-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a91b6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a91ca-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a91e8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a91fc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9210-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9224-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9238-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9256-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a926a-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a927e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9292-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a92a6-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a92ba-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a92d8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a92ec-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9300-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9314-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9328-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a933c-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9350-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a936e-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9382-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9396-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a93aa-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a93c8-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a93dc-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a93f0-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9404-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a9418-cbfc-11ee-9ff4-7085c27bb25b',
#   'd10a942c-cbfc-11ee-9ff4-7085c27bb25b',
#   'c18c85d4-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c869c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c86ce-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c86e2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8700-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8714-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8728-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8746-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c875a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c876e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c878c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c87be-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c87d2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c87f0-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8804-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8818-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c882c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8840-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c885e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8872-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8886-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c889a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c88ae-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c88c2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c88e0-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c88f4-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8908-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c891c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8930-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8944-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8962-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8976-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c898a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c899e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c89b2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c89c6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c89e4-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c89f8-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a0c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a20-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a34-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a48-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a5c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a7a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8a8e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8aa2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ab6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8aca-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ade-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8af2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b10-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b24-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b38-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b60-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b7e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8b92-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ba6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8bba-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8bce-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8be2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c00-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c14-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c28-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c3c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c50-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c6e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c82-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8c96-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8caa-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8cc8-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8cdc-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8cf0-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d04-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d18-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d2c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d40-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d5e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d72-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d86-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8d9a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8db8-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8dcc-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8de0-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8df4-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e08-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e1c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e30-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e44-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e62-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e76-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e8a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8e9e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8eb2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ec6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ee4-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f02-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f20-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f34-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f48-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f5c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f70-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8f8e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8fa2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8fb6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8fca-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8fde-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c8ff2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9006-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9024-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9038-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c904c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9060-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c907e-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9092-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c90a6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c90ba-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c90ce-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c90e2-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c90f6-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c910a-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9128-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c913c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9150-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9164-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c9178-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c918c-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c91a0-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c91be-ccb8-11ee-a2f6-7085c27bb25b',
#   'c18c91d2-ccb8-11ee-a2f6-7085c27bb25b',
#   ...],
#  'embeddings': None,
#  'metadatas': [{'source': 'documents/Big Panda/Big_Panda.md'},
#   {'source': 'documents/Boulder Bear/Boulder_Bear.md'},
#   {'source': 'documents/Clockwork Spider/Clockwork_Spider.md'},
#   {'source': 'documents/Corsair Jackal/Corsair_Jackal.md'},
#   {'source': 'documents/Dextorous Spider/Dextorous_Spider.md'},
#   {'source': 'documents/Dizzy Panda/Dizzy_Panda.md'},
#   {'source': 'documents/Electric Panda/Electric_Panda.md'},
#   {'source': 'documents/Eloquent Panda/Eloquent_Panda.md'},
#   {'source': 'documents/Flyfox/Flyfox.md'},
#   {'source': 'documents/Foxy Panda/Foxy_Panda.md'},
#   {'source': 'documents/Ghost Jackal/Ghost_Jackal.md'},
#   {'source': 'documents/Gibberish Panda/Gibberish_Panda.md'},
#   {'source': 'documents/HolyWater/HolyWater.md'},
#   {'source': 'documents/Impersonating Panda/Impersonating_Panda.md'},
#   {'source': 'documents/Knockout Spider/Knockout_Spider.md'},
#   {'source': 'documents/Kumsong121/Kumsong121.md'},
#   {'source': 'documents/Magnetic Spider/Magnetic_Spider.md'},
#   {'source': 'documents/Outlaw Spider/Outlaw_Spider.md'},
#   {'source': 'documents/Overlord Spider/Overlord_Spider.md'},
#   {'source': 'documents/Pale Panda/Pale_Panda.md'},
#   {'source': 'documents/ParkingBear/ParkingBear.md'},
#   {'source': 'documents/Poisonous Panda/Poisonous_Panda.md'},
#   {'source': 'documents/Predator Panda/Predator_Panda.md'},
#   {'source': 'documents/Sabre Panda/Sabre_Panda.md'},
#   {'source': 'documents/Singing Spider/Singing_Spider.md'},
#   {'source': 'documents/Solar Spider/Solar_Spider.md'},
#   {'source': 'documents/Spicy Panda/Spicy_Panda.md'},
#   {'source': 'documents/Test Panda/Test_Panda.md'},
#   {'source': 'documents/Toxic Panda/Toxic_Panda.md'},
#   {'source': 'documents/Union Panda/Union_Panda.md'},
#   {'source': 'documents/Union Spider/Union_Spider.md'},
#   {'source': 'documents/Viking Jackal/Viking_Jackal.md'},
#   {'source': 'documents/Wet Panda/Wet_Panda.md'},
#   {'source': 'documents/AeroBlade/AeroBlade.md'},
#   {'source': 'documents/Aggah/Aggah.md'},
#   {'source': 'documents/Aggah/Aggah.md'},
#   {'source': 'documents/Aggah/Aggah.md'},
#   {'source': 'documents/Agrius/Agrius.md'},
#   {'source': 'documents/Allanite/Allanite.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/ALPHV, BlackCat Gang/ALPHV,_BlackCat_Gang.md'},
#   {'source': 'documents/Scattered Spider/Scattered_Spider.md'},
#   {'source': 'documents/Scattered Spider/Scattered_Spider.md'},
#   {'source': 'documents/Anchor Panda, APT 14/Anchor_Panda,_APT_14.md'},
#   {'source': 'documents/Antlion/Antlion.md'},
#   {'source': 'documents/Aoqin Dragon/Aoqin_Dragon.md'},
#   {'source': 'documents/APT 3, Gothic Panda, Buckeye/APT_3,_Gothic_Panda,_Buckeye.md'},
#   {'source': 'documents/APT 3, Gothic Panda, Buckeye/APT_3,_Gothic_Panda,_Buckeye.md'},
#   {'source': 'documents/APT 3, Gothic Panda, Buckeye/APT_3,_Gothic_Panda,_Buckeye.md'},
#   {'source': 'documents/APT 4, Maverick Panda, Wisp Team/APT_4,_Maverick_Panda,_Wisp_Team.md'},
#   {'source': 'documents/APT 4, Maverick Panda, Wisp Team/APT_4,_Maverick_Panda,_Wisp_Team.md'},
#   {'source': 'documents/APT 5, Keyhole Panda/APT_5,_Keyhole_Panda.md'},
#   {'source': 'documents/APT 5, Keyhole Panda/APT_5,_Keyhole_Panda.md'},
#   {'source': 'documents/APT 6/APT_6.md'},
#   {'source': 'documents/APT 12, Numbered Panda/APT_12,_Numbered_Panda.md'},
#   {'source': 'documents/APT 12, Numbered Panda/APT_12,_Numbered_Panda.md'},
#   {'source': 'documents/APT 12, Numbered Panda/APT_12,_Numbered_Panda.md'},
#   {'source': 'documents/APT 16, SVCMONDR/APT_16,_SVCMONDR.md'},
#   {'source': 'documents/APT 17, Deputy Dog, Elderwood, Sneaky Panda/APT_17,_Deputy_Dog,_Elderwood,_Sneaky_Panda.md'},
#   {'source': 'documents/APT 17, Deputy Dog, Elderwood, Sneaky Panda/APT_17,_Deputy_Dog,_Elderwood,_Sneaky_Panda.md'},
#   {'source': 'documents/APT 17, Deputy Dog, Elderwood, Sneaky Panda/APT_17,_Deputy_Dog,_Elderwood,_Sneaky_Panda.md'},
#   {'source': 'documents/APT 17, Deputy Dog, Elderwood, Sneaky Panda/APT_17,_Deputy_Dog,_Elderwood,_Sneaky_Panda.md'},
#   {'source': 'documents/APT 18, Dynamite Panda, Wekby/APT_18,_Dynamite_Panda,_Wekby.md'},
#   {'source': 'documents/APT 18, Dynamite Panda, Wekby/APT_18,_Dynamite_Panda,_Wekby.md'},
#   {'source': 'documents/APT 19, Deep Panda, C0d0so0/APT_19,_Deep_Panda,_C0d0so0.md'},
#   {'source': 'documents/APT 19, Deep Panda, C0d0so0/APT_19,_Deep_Panda,_C0d0so0.md'},
#   {'source': 'documents/APT 19, Deep Panda, C0d0so0/APT_19,_Deep_Panda,_C0d0so0.md'},
#   {'source': 'documents/APT 19, Deep Panda, C0d0so0/APT_19,_Deep_Panda,_C0d0so0.md'},
#   {'source': 'documents/APT 19, Deep Panda, C0d0so0/APT_19,_Deep_Panda,_C0d0so0.md'},
#   {'source': 'documents/APT 20, Violin Panda/APT_20,_Violin_Panda.md'},
#   {'source': 'documents/APT 20, Violin Panda/APT_20,_Violin_Panda.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
#   {'source': 'documents/APT 29, Cozy Bear, The Dukes/APT_29,_Cozy_Bear,_The_Dukes.md'},
# ...
#   'Last year we created a private report on a malware framework that we named MATA, which we attribute, with low confidence, to the Lazarus group. This framework included several components, such as a loader, orchestrator and plug-ins. Initially, this framework targeted Windows and Linux. However, in April we discovered a suspicious macOS file uploaded to VirusTotal using a rule to detect the MATA malware framework. After looking into this malware, we confirmed that it was a macOS variant of the MATA malware. The malware developers Trojanized an open-source two-factor authentication application and utilized another open-source application template. While investigating, to find more solid evidence for attribution, we found an old Manuscrypt strain that used a similar configuration structure. We also discovered a cluster of C2 servers probably related to this campaign.\nThe MATA framework was not the only way that Lazarus targeted macOS. We also observed a cluster of activity linked to Operation AppleJeus. The other was similar to the macOS malware used in a campaign that we call TangDaiwbo. This is a multi-platform cryptocurrency exchange campaign: Lazarus utilizes macro-embedded Office documents and spreads PowerShell or macOS malware, depending on the victim’s system.\nEarly this year, we reported improvements in a Lazarus campaign targeting a cryptocurrency business. In this campaign, Lazarus adopted a downloader that sends compromised host information and selectively fetches the next-stage payload. Recently, we identified a Lazarus campaign with similar strategies, but targeting academic and automotive sectors. Lazarus also adopted new methods to deliver its tools. First of all, the group elaborated its weaponized document by adopting remote template injection techniques. Previously, Lazarus delivered macro-embedded documents to the victim, but the group has now applied one more stage to hinder detection. The group also utilized an open-source PDF reader named Sumatra PDF to make Trojanized applications. They created a Trojanized PDF reader, sending it to the victim with a crafted PDF file. If the victim opens this file, the Trojanised PDF viewer implants malicious files and shows decoy documents to deceive the victim. The actor delivers the final payload very carefully, and executes it in memory. Fortunately, we were able to get the final payload and confirm that it was a Manuscrypt variant that we had already described. We also found that it’s the same malware variant that the US CISA (Cybersecurity and Infrastructure Security Agency) recently reported, named COPPERHEDGE.',
#   'Following our report describing the long-standing PhantomLance campaign in Southeast Asia, we published a private report providing detailed attribution based on discovered overlaps with reported campaigns of the OceanLotus APT. In particular, we found multiple code similarities with the previous Android campaign, as well as similarities in macOS backdoors, infrastructure overlap with Windows backdoors and a couple of cross-platform resemblances. Based on our research, we believe, with medium confidence, that PhantomLance is a modern Android campaign conducted by OceanLotus. Apart from the attribution details, we described the actor’s spreading strategy using techniques to bypass app market filters. We also provided additional details about samples associated with previously reported suspected infrastructure, as well as the latest sample deployed in 2020 that uses Firebase to decrypt its payload.\nAdditionally, OceanLotus has been using new variants of its multi-stage loader since the second half of 2019. The new variants use target-specific information (username, hostname, etc.) of the targeted host that they obtained beforehand, in order to ensure their final implant is deployed on the right victim. The group continues to deploy its backdoor implant, as well as Cobalt Strike Beacon, configuring them with updated infrastructure.\nOther interesting discoveries\nThe Deceptikons APT is a long-running espionage group believed to have been providing mercenary services for almost a decade now. The group is not technically sophisticated and has not, to our knowledge, deployed zero-day exploits. The Deceptikons infrastructure and malware set is clever, rather than technically advanced. It is also highly persistent and in many ways reminds us of WildNeutron. Deceptikon’s repeated targeting of commercial and non-governmental organizations is somewhat unusual for APT actors. In 2019, Deceptikons spear-phished a set of European law firms, deploying PowerShell scripts. As in previous campaigns, the actor used modified LNK files requiring user interaction to initially compromise systems and execute a PowerShell backdoor. In all likelihood, the group’s motivations included obtaining specific financial information, details of negotiations, and perhaps even evidence of the law firms’ clientele.',
#   'MagicScroll (aka AcidBox) is the name we’ve given to a sophisticated malware framework, whose main purpose is to decrypt and load an arbitrary payload in kernel mode. The framework consists of several stages. The first stage is a Windows security provider that is loaded by the system on boot and executed in user mode. This decrypts and runs a second payload, which is physically stored in the registry. Although we weren’t able to find a victim with this second stage, we were able to find a file that matches the expected format of the second stage. This second stage payload utilizes a well-known vulnerability in a VirtualBox driver (CVE-2008-3431) to load the third stage, which is designed to run in kernel mode. The kernel mode payload is decrypted from a resource from the second stage, using the key retrieved from the registry. Unfortunately, we couldn’t find a decryption key to decrypt the third stage payload, so we don’t know what the last part of this malware framework looks like. Although the code is quite sophisticated, we couldn’t identify any similarity with other known frameworks.\nAarogya Setu is the name of a mandatory COVID-19 mobile tracking app developed by the National Informatics Centre, an organization that comes under the Ministry of Electronics and Information Technology in India. It allows its users to connect to essential health services in India. With cyber criminals and APT actors taking advantage of pandemic-tracking applications to distribute Trojanized mobile apps, we investigated and identified apps that mimic the appearance and behavior of the legitimate Aarogya Setu app while deploying Android RATs. We consider one of these to be a new version of a RAT that we previously reported being used by the Transparent Tribe threat actor.\nFinal thoughts\nThe threat landscape isn’t always full of “groundbreaking” events.\xa0 However, a review of the activities of APT threat actors indicates that there are always interesting developments. Our regular quarterly reviews are intended to highlight these key developments.\nHere are the main trends that we’ve seen in Q2 2020.',
#   'Geo-politics remains an important motive for some APT threat actors, as shown in the activities of MuddyWater, the compromise of the Middle East Eye website and the campaigns of CloudComputating and HoneyMyte groups.\nAs is clear from the activities of Lazarus and BlueNoroff, financial gain is another driver for some threat actors – including the use of ransomware attacks.\nWhile Southeast Asia continues to be an active region for APT activities, this quarter we have also observed heavy activity by Chinese-speaking groups, including ShadowPad, HoneyMyte, CactusPete, CloudComputating and SixLittleMonkeys.\nAPT threat actors continue to exploit software vulnerabilities – examples this quarter include Hades and MagicScroll.\nWe have noted before that the use of mobile implants is no longer a novelty, and this quarter is no exception, as illustrated by the PhantomLance campaign.\nIt is clear that APT actors, like opportunistic cybercriminals, continue to exploit the COVID-19 pandemic as a theme to lure potential victims. However, we would note once again that this doesn’t represent a shift in TTPs.\n\nAs always, we would note that our reports are the product of our visibility into the threat landscape. However, it should be borne in mind that, while we strive to continually improve, there is always the possibility that other sophisticated attacks may fly under our radar.\n\nAPT\nBackdoor\nChinese-speaking cybercrime\nFinancial malware\nLazarus\nMalware\nRansomware\nRussian-speaking cybercrime\nTargeted attacks\nTurla\n\nAuthors\n\nGReAT\n\nAPT trends report Q2 2020 \n Your email address will not be published. Required fields are marked *Name * \nEmail *\n\nCancel\n\nTable of Contents\n\nThe most remarkable findingsRussian-speaking activityChinese-speaking activityMiddle EastSouthеast Asia and Korean PeninsulaOther interesting discoveriesFinal thoughts\n\nGReAT webinars\n\nGReAT Ideas. Balalaika Edition\n\nBoris Larin\n\nDenis Legezo\n\nGReAT Ideas. Green Tea Edition\n\nJohn Hultquist\n\nBrian Bartholomew\n\nSuguru Ishimaru\n\nVitaly Kamluk\n\nSeongsu Park\n\nYusuke Niwa\n\nMotohiko Sato\n\nGReAT Ideas. Powered by SAS: malware attribution and next-gen IoT honeypots\n\nMarco Preuss\n\nDenis Legezo\n\nCostin Raiu',
#   'Yusuke Niwa\n\nMotohiko Sato\n\nGReAT Ideas. Powered by SAS: malware attribution and next-gen IoT honeypots\n\nMarco Preuss\n\nDenis Legezo\n\nCostin Raiu\n\nKurt Baumgartner\n\nDan Demeter\n\nYaroslav Shmelev\n\nGReAT Ideas. Powered by SAS: threat actors advance on new fronts\n\nIvan Kwiatkowski\n\nMaher Yamout\n\nNoushin Shabab\n\nPierre Delcher\n\nFélix Aime\n\nGiampaolo Dedola\n\nSantiago Pontiroli\n\nGReAT Ideas. Powered by SAS: threat hunting and new techniques\n\nDmitry Bestuzhev\n\nCostin Raiu\n\nPierre Delcher\n\nBrian Bartholomew\n\nBoris Larin\n\nAriel Jungheit\n\nFabio Assolini\n\nFrom the same authors\n\nCoyote: A multi-stage banking Trojan abusing the Squirrel installer\n\nFakeSG campaign, Akira ransomware and AMOS macOS stealer\n\nAdvanced threat predictions for 2024\n\nStealer for PIX payment system, new Lumar stealer and Rhysida ransomware\n\nUpdated MATA attacks industrial companies in Eastern Europe\n\nSubscribe to our weekly e-mails\nThe hottest research right in your inbox\n\nEmail*\n\nI agree to provide my email address to “AO Kaspersky Lab” to receive information about new posts on the site. I understand that I can withdraw this consent at any time via e-mail by clicking the “unsubscribe” link that I find at the bottom of any e-mail sent to me for the purposes mentioned above.\n\nSubscribe\n\nIn the same category\n\nHrServ – Previously unknown web shell used in APT attack\n\nModern Asian APT groups’ tactics, techniques and procedures (TTPs)\n\nA cascade of compromise: unveiling Lazarus’ new campaign\n\nHow to catch a wild triangle\n\nStripedFly: Perennially flying under the radar\n\nLatest Posts\n\nMalware descriptions\n\nCracked software beats gold: new macOS backdoor stealing cryptowallets\n\nSergey Puzan\n\nKaspersky Security Bulletin\n\nDark web threats and dark market predictions for 2024\n\nSergey Lozhkin\n\nAnna Pavlovskaya\n\nKaspersky Security Services\n\nResearch\n\nA lightweight method to detect potential iOS malware\n\nMaher Yamout\n\nResearch\n\nOperation Triangulation: The last (hardware) mystery',
#   'Sergey Lozhkin\n\nAnna Pavlovskaya\n\nKaspersky Security Services\n\nResearch\n\nA lightweight method to detect potential iOS malware\n\nMaher Yamout\n\nResearch\n\nOperation Triangulation: The last (hardware) mystery\n\nBoris Larin\n\nLatest Webinars\n\nTechnologies and services\n\n60 min\n\nThe Future of AI in cybersecurity: what to expect in 2024\n\nVladimir Dashchenko\n\nVictor Sergeev\n\nVladislav Tushkanov\n\nDennis Kipker\n\nThreat intelligence and IR\n\n70 min\n\nResponding to a data breach: a step-by-step guide\n\nAnna Pavlovskaya\n\nCyberthreat talks\n\n60 min\n\n2024 Advanced persistent threat predictions\n\nIgor Kuznetsov\n\nDavid Emm\n\nMarc Rivero\n\nDan Demeter\n\nSherif Magdy\n\nCyberthreat talks\n\n60 min\n\nOverview of modern car compromise techniques and methods of protection\n\nAlexander Kozlov\n\nSergey Anufrienko\n\nReports\n\nHrServ – Previously unknown web shell used in APT attack\n\nIn this report Kaspersky researchers provide an analysis of the previously unknown HrServ web shell, which exhibits both APT and crimeware features and has likely been active since 2021.\n\nModern Asian APT groups’ tactics, techniques and procedures (TTPs)\n\nAsian APT groups target various organizations from a multitude of regions and industries. We created this report to provide the cybersecurity community with the best-prepared intelligence data to effectively counteract Asian APT groups.\n\nA cascade of compromise: unveiling Lazarus’ new campaign\n\nWe unveil a Lazarus campaign exploiting security company products and examine its intricate connections with other campaigns\n\nHow to catch a wild triangle\n\nHow Kaspersky researchers obtained all stages of the Operation Triangulation campaign targeting iPhones and iPads, including zero-day exploits, validators, TriangleDB implant and additional modules.\n\nSubscribe to our weekly e-mails\nThe hottest research right in your inbox\n\nEmail*\n\nI agree to provide my email address to “AO Kaspersky Lab” to receive information about new posts on the site. I understand that I can withdraw this consent at any time via e-mail by clicking the “unsubscribe” link that I find at the bottom of any e-mail sent to me for the purposes mentioned above.\n\nSubscribe\n\nThreatsThreats',
#   'Subscribe\n\nThreatsThreats\n\nAPT (Targeted attacks)\nSecure environment (IoT)\nMobile threats\nFinancial threats\nSpam and phishing\nIndustrial threats\nWeb threats\nVulnerabilities and exploits\n\nCategoriesCategories\n\nAPT reports\nMalware descriptions\nSecurity Bulletin\nMalware reports\nSpam and phishing reports\nSecurity technologies\nResearch\nPublications\n\nOther sections\n\nArchive\nAll tags\nWebinars\nAPT Logbook\nStatistics\nEncyclopedia\nThreats descriptions\nKSB 2023\n\n© 2024 AO Kaspersky Lab. All Rights Reserved.\nRegistered trademarks and service marks are the property of their respective owners.\n\nPrivacy Policy\nLicense Agreement\nCookies\n\nSubscribe to our weekly e-mails\nThe hottest research right in your inbox\n\nEmail*\n\nI agree to provide my email address to “AO Kaspersky Lab” to receive information about new posts on the site. I understand that I can withdraw this consent at any time via e-mail by clicking the “unsubscribe” link that I find at the bottom of any e-mail sent to me for the purposes mentioned above.\n\nSubscribe',
#   ...]}

# %% [markdown]
# # Query ETDA listed threat actor reports and information

# %% [markdown]
# ## Setup retriever, prompt and llm
# Load five similar chunks using the retriever and review the output through OpenAI GPT on low temperature (randomness) using a specialized Langchain RAG prompt

# %%
retriever = db.as_retriever(search_kwargs={"k":5})
prompt = hub.pull("rlm/rag-prompt")
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0, openai_api_key=openai.api_key)

# %% [markdown]
# ## Setup chain that also reports on sources found
# https://python.langchain.com/docs/use_cases/question_answering/sources

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain_from_docs = (
    RunnablePassthrough.assign(context=(lambda x: format_docs(x["context"])))
    | prompt
    | llm
    | StrOutputParser()
)

rag_chain_with_source = RunnableParallel(
    {"context": retriever, "question": RunnablePassthrough()}
).assign(answer=rag_chain_from_docs)

# %% [markdown]
# # Example query with successful and complete answer (see LLM answer at bottom of output)

# %%
rag_chain_with_source.invoke("What vulnerabilities has cl0p exploited?")
# Out:
# {'context': [Document(page_content='Cl0p ransomware claims to have attacked Saks Fifth Avenue (BleepingComputer)\nThe threat actor has not yet disclosed any additional information, such as what all data it stole from the luxury brand retailer\'s systems, or details about any ongoing ransom negotiations.\nBleepingComputer has confirmed, however, the cyber security incident is linked to Clop\'s ongoing attacks targeting GoAnywhere servers vulnerable to a security flaw.\nThe flaw, now tracked as CVE-2023-0669, enables attackers to gain remote code execution on unpatched GoAnywhere MFT instances with their administrative console exposed to Internet access.\nGoAnywhere MFT\'s developer Fortra (formerly HelpSystems) had previously disclosed to its customers that the vulnerability had been exploited as a zero-day in the wild and urged customers to patch their systems. The official advisory remains hidden to the public, but was earlier made public by investigative reporter Brian Krebs.\nIn February, Clop reached out to BleepingComputer and claimed it had breached 130+ organizations and stolen their data over the course of ten days by exploiting this particular vulnerability on enterprise servers.\nThis month, Hitachi Energy disclosed a data breach by Clop resulting from the same\xa0zero-day.\nSaks says no real customer data stolen\nBleepingComputer reached out to Saks to better understand the scope of this incident. A spokesperson confirmed the incident was linked to Fortra.\n"Fortra, a vendor to Saks and many other companies, recently experienced a data security incident that led to mock customer data being taken from a storage location used by Saks," a Saks spokesperson told BleepingComputer.\n"The mock customer data does not include real customer or payment card information and is solely used to simulate customer orders for testing purposes."\nWhile the retail giant states no "real" customer data or payment information was stolen, it did not answer our follow up question, as to whether corporate or employee data was compromised in this incident.\n"We take information security very seriously, and are conducting an ongoing investigation into this incident alongside outside experts and law enforcement. As organizations increasingly face cybersecurity threats, we remain committed to ensuring the safety of the information we hold," concluded Saks in its statement to us.\nFor the avoidance of doubt, Saks OFF 5TH—while previously a subsidiary of Saks Inc., is now a separate company and as such not linked to this incident.', metadata={'source': 'documents/FIN11/Clop_ransomware_claims_Saks_Fifth_Avenue,_retailer_says_mock_data_stolen.md'}),
#   Document(page_content="Since then, Clop has been responsible for numerous large-scale ransomware attacks, including those against\xa0Maastricht University,\xa0Software AG IT,\xa0ExecuPharm, and\xa0Indiabulls.\nMore recently, Clop had been\xa0stealing data from Accellion FTA file transfer devices\xa0using a zero-day vulnerability and then threatening to release the data if not paid $10 million or more.\nSome of the victims of Accellion attacks include\xa0energy giant Shell,\xa0cybersecurity firm Qualys,\xa0Flagstar Bank, the\xa0University of Miami, and the\xa0University of California, to name a few.\nThe Ukrainian police estimate that Clop's total damages reach as high as $500 million.", metadata={'source': 'documents/FIN11/Clop_ransomware_is_back_in_business_after_recent_arrests.md'}),
#   Document(page_content='Clop\nData Breach\nData Leak\nRansomware\nSchneider Electric\nSiemens Energy\n\nBill Toulas\n\nBill Toulas is a tech writer and infosec news reporter with over a decade of experience working on various online publications, covering open-source, Linux, malware, data breach incidents, and hacks.\n\nPrevious Article \nNext Article\n\nComments\n\nEndangeredPootisBird  - 7 months ago\n\nThe company also provides a wide range of cybersecurity consulting services for the oil and gas industry, including incident response plans, vulnerability assessment, and patch management.\n\nThe irony\n\nPost a Comment Community Rules\n\nYou need to login in order to post a comment\n\nNot a member yet? Register Now\n\nYou may also like:\n\nPopular Stories\n\nHackers used new Windows Defender zero-day to drop DarkMe malware\n\nMicrosoft February 2024 Patch Tuesday fixes 2 zero-days, 73 flaws\n\nFollow us:\n\nMain Sections\n\nNews\nVPN Buyer Guides\nDownloads\nVirus Removal Guides\nTutorials\nStartup Database\nUninstall Database\nGlossary\n\nCommunity\n\nForums\nForum Rules\nChat\n\nUseful Resources\n\nWelcome Guide\nSitemap\n\nCompany\n\nAbout BleepingComputer\nContact Us\nSend us a Tip!\nAdvertising\nWrite for BleepingComputer\nSocial & Feeds\nChangelog\n\nTerms of Use -  Privacy Policy - Ethics Statement - Affiliate Disclosure\n\nCopyright @ 2003 - 2024  Bleeping Computer® LLC  - All Rights Reserved\n\nLogin\n\nUsername\n\nPassword\n\nRemember Me\n\nSign in anonymously\n\nSign in with Twitter\n\nNot a member yet? Register Now\n\nReporter\n\nHelp us understand the problem. What is going on with this comment?\n\nSpam\n\nAbusive or Harmful\n\nInappropriate content\n\nStrong language\n\nOther\n\nRead our posting guidelinese to learn what content is prohibited.\n\nSubmitting...\nSUBMIT', metadata={'source': 'documents/FIN11/Siemens_Energy_confirms_data_breach_after_MOVEit_data-theft_attack.md'}),
#   Document(page_content='Clop leak site\nWhile still unclear if Clop\xa0is behind these Accellion attacks or they\'re collaborating with another group, a\xa0joint statement from\xa0Mandiant and Accellion\xa0shed more light on these\xa0attacks\xa0also linking them to a second operation, the FIN11 cybercrime group.\nBleepingComputer has reported multiple data breaches affecting companies and\xa0organizations after these threat actors successfully compromised their Accellion FTA servers and exfiltrated sensitive information.\nStarting with January, we reported attacks on energy giant Shell,\xa0cybersecurity firm Qualys,\xa0supermarket giant Kroger, the\xa0Reserve Bank of New Zealand, Singtel, the\xa0Australian Securities and Investments Commission (ASIC), the\xa0Office of the Washington State Auditor\xa0("SAO"), as well as multiple universities and other organizations.\nFive Eyes members also issued a\xa0joint security advisory\xa0in February about ongoing attacks and extortion attempts targeting orgs that use vulnerable Accellion File Transfer Appliance (FTA) versions.\nIn related news,\xa0Brown University, a private Ivy League research university, is still working on bringing systems online after it had to disable them following a\xa0cyberattack on Tuesday.\n\nRelated Articles:\nIntegris Health says data breach impacts 2.4 million patientsBank of America warns customers of data breach after vendor hackFCC orders telecom carriers to report PII data breaches within 30 daysData breaches at Viamedis and Almerys impact 33 million in FranceData breach at French healthcare services firm puts millions at risk\n\nAccellion\nData Breach\nStanford\nUniversity\n\nSergiu Gatlan\n\nSergiu is a news reporter who has covered the latest cybersecurity and technology developments for over a decade. Email or Twitter DMs for tips.\n\nPrevious Article \nNext Article\n\nPost a Comment Community Rules\n\nYou need to login in order to post a comment\n\nNot a member yet? Register Now\n\nYou may also like:\n\nPopular Stories\n\nHackers used new Windows Defender zero-day to drop DarkMe malware\n\nMicrosoft February 2024 Patch Tuesday fixes 2 zero-days, 73 flaws\n\nFollow us:\n\nMain Sections\n\nNews\nVPN Buyer Guides\nDownloads\nVirus Removal Guides\nTutorials\nStartup Database\nUninstall Database\nGlossary\n\nCommunity\n\nForums\nForum Rules\nChat\n\nUseful Resources\n\nWelcome Guide\nSitemap\n\nCompany', metadata={'source': 'documents/FIN11/Ransomware_gang_leaks_data_from_Stanford,_Maryland_universities.md'}),
#   Document(page_content='\u200bThe Clop ransomware gang has claimed responsibility for the CVE-2023-34362 MOVEit Transfer attacks on June 5 in a statement shared with BleepingComputer, with the cybercrime gang saying it breached the MOVEit servers of "hundreds of companies."\nKroll also uncovered evidence that Clop had been actively testing exploits for the now-patched MOVEit zero-day since 2021 and researching methods to extract data from compromised servers since at least April 2022.\nClop\'s involvement in this extensive data theft campaign is part of a broader pattern of targeting MFT platforms.\nPrevious instances include the breach of Accellion FTA servers in December 2020, SolarWinds Serv-U servers in 2021, and the widespread exploitation of GoAnywhere MFT servers earlier this year in January.\nClop already extorting impacted organizations\nThe Clop gang began extorting organizations affected by the MOVEit data theft attacks almost two weeks ago, on June 15, by publicly listing their names on Clop\'s dark web data leak site.\nShell, the University of Georgia (UGA) and University System of Georgia (USG), Heidelberger Druck, UnitedHealthcare Student Resources (UHSR), and Landal Greenparks are just some of the organizations that have confirmed to BleepingComputer that they were impacted.\nOther victims that already disclosed breaches related to the MOVEit Transfer attacks include the U.S. state of Missouri, the U.S. state of Illinois, Zellis (along with its customers BBC, Boots, Aer Lingus, and Ireland\'s HSE), Ofcam, the government of Nova Scotia, the American Board of Internal Medicine, and Extreme Networks.\nThe U.S. Cybersecurity and Infrastructure Security Agency (CISA) disclosed that several U.S. federal agencies have also been compromised, as reported by CNN. Federal News Network said the attacks also impacted two U.S. Department of Energy (DOE) entities.\nProgress warned MOVEit Transfer customers last week to restrict HTTP access to their servers after info on a new SQL injection (SQLi) security flaw (CVE-2023-35708) was published online.\nThat warning came after another advisory disclosed several other critical SQL injection vulnerabilities collectively tracked as CVE-2023-35036.', metadata={'source': 'documents/FIN11/Hackers_steal_data_of_45,000_New_York_City_students_in_MOVEit_breach.md'})],
#  'question': 'What vulnerabilities has cl0p exploited?',
#  'answer': 'Cl0p ransomware has exploited vulnerabilities in GoAnywhere servers, specifically targeting servers vulnerable to a security flaw tracked as CVE-2023-0669. The ransomware gang has also been involved in data theft campaigns targeting MFT platforms, including Accellion FTA servers, SolarWinds Serv-U servers, and MOVEit Transfer servers. Clop has been responsible for numerous large-scale ransomware attacks, including those against Maastricht University, Software AG IT, ExecuPharm, and Indiabulls.'}

# %% [markdown]
# # Example query with unsuccessful output due to irrelevant chunks found (see LLM answer at bottom of output)

# %%
rag_chain_with_source.invoke("Describe vulnerabilities that threat actor cl0p has exploited throughout various campaigns.")
# Out:
# {'context': [Document(page_content='Reported hacking operations\n\n2007: Hupigon and Pirpi Backdoors\nhttps://www.fireeye.com/blog/threat-research/2010/11/ie-0-day-hupigon-joins-the-party.html\n\n2014-04: Operation “Clandestine Fox”\nFireEye Research Labs identified a new Internet Explorer (IE) zero-day exploit used in targeted attacks.  The vulnerability affects IE6 through IE11, but the attack is targeting IE9 through IE11.  This zero-day bypasses both ASLR and DEP. Microsoft has assigned CVE-2014-1776 to the vulnerability and released security advisory to track this issue.\nhttps://www.fireeye.com/blog/threat-research/2014/04/new-zero-day-exploit-targeting-internet-explorer-versions-9-through-11-identified-in-targeted-attacks.html\n\n2014-06: Operation “Clandestine Fox”, Part Deux\nWhile Microsoft quickly released a patch to help close the door on future compromises, we have now observed the threat actors behind “Operation Clandestine Fox” shifting their point of attack and using a new vector to target their victims: social networking.\nhttps://www.fireeye.com/blog/threat-research/2014/06/clandestine-fox-part-deux.html\n\n2014-11: Operation “Double Tap”\nThis actor initiated their most recent campaign on November 19, 2014 targeting multiple organizations. The attacker leveraged multiple exploits, targeting both CVE-2014-6332 and CVE-2014-4113.\nhttps://www.fireeye.com/blog/threat-research/2014/11/operation_doubletap.html\n\n2015-06: Operation “Clandestine Wolf”\nIn the last several weeks, APT3 actors launched a large-scale phishing campaign against organizations in the following industries: Aerospace and Defense, Construction and Engineering, High Tech, Telecommunications and Transportation.\nhttps://www.fireeye.com/blog/threat-research/2015/06/operation-clandestine-wolf-adobe-flash-zero-day.html', metadata={'source': 'documents/APT 3, Gothic Panda, Buckeye/APT_3,_Gothic_Panda,_Buckeye.md'}),
#   Document(page_content='Reported hacking operations\n\n2007: Hupigon and Pirpi Backdoors\nhttps://www.fireeye.com/blog/threat-research/2010/11/ie-0-day-hupigon-joins-the-party.html\n\n2014-04: Operation “Clandestine Fox”\nFireEye Research Labs identified a new Internet Explorer (IE) zero-day exploit used in targeted attacks.  The vulnerability affects IE6 through IE11, but the attack is targeting IE9 through IE11.  This zero-day bypasses both ASLR and DEP. Microsoft has assigned CVE-2014-1776 to the vulnerability and released security advisory to track this issue.\nhttps://www.fireeye.com/blog/threat-research/2014/04/new-zero-day-exploit-targeting-internet-explorer-versions-9-through-11-identified-in-targeted-attacks.html\n\n2014-06: Operation “Clandestine Fox”, Part Deux\nWhile Microsoft quickly released a patch to help close the door on future compromises, we have now observed the threat actors behind “Operation Clandestine Fox” shifting their point of attack and using a new vector to target their victims: social networking.\nhttps://www.fireeye.com/blog/threat-research/2014/06/clandestine-fox-part-deux.html\n\n2014-11: Operation “Double Tap”\nThis actor initiated their most recent campaign on November 19, 2014 targeting multiple organizations. The attacker leveraged multiple exploits, targeting both CVE-2014-6332 and CVE-2014-4113.\nhttps://www.fireeye.com/blog/threat-research/2014/11/operation_doubletap.html\n\n2015-06: Operation “Clandestine Wolf”\nIn the last several weeks, APT3 actors launched a large-scale phishing campaign against organizations in the following industries: Aerospace and Defense, Construction and Engineering, High Tech, Telecommunications and Transportation.\nhttps://www.fireeye.com/blog/threat-research/2015/06/operation-clandestine-wolf-adobe-flash-zero-day.html', metadata={'source': 'documents/APT 3, Gothic Panda, Buckeye/APT_3,_Gothic_Panda,_Buckeye.md'}),
#   Document(page_content='Threat actor: Operation Shady RAT\n\nUUID: 3227cd76-90c0-4139-83c0-afbdb298d1f2\n\nFirst seen: 2006\n\nSource last modified: 2021-05-21\n\nThreat actor aliases\n\nOperation Shady RAT (McAfee)\n\nDescription\n\n(McAfee) With the goal of raising the level of public awareness today we are publishing the most comprehensive analysis ever revealed of victim profiles from a five year targeted operation by one specific actor—Operation Shady RAT, as I have named it at McAfee (RAT is a common acronym in the industry which stands for Remote Access Tool).\n\nThis is not a new attack, and the vast majority of the victims have long since remediated these specific infections (although whether most realized the seriousness of the intrusion or simply cleaned up the infected machine without further analysis into the data loss is an open question). McAfee has detected the malware variants and other relevant indicators for years with Generic Downloader.x and Generic BackDoor.t heuristic signatures (those who have had prior experience with this specific adversary may recognize it by the use of encrypted HTML comments in web pages that serve as a command channel to the infected machine).\n\nMcAfee has gained access to one specific Command & Control server used by the intruders. We have collected logs that reveal the full extent of the victim population since mid-2006 when the log collection began. Note that the actual intrusion activity may have begun well before that time but that is the earliest evidence we have for the start of the compromises. The compromises themselves were standard procedure for these types of targeted intrusions: a spear-phishing email containing an exploit is sent to an individual with the right level of access at the company, and the exploit when opened on an unpatched system will trigger a download of the implant malware. That malware will execute and initiate a backdoor communication channel to the Command & Control web server and interpret the instructions encoded in the hidden comments embedded in the webpage code. This will be quickly followed by live intruders jumping on to the infected machine and proceeding to quickly escalate privileges and move laterally within the organization to establish new persistent footholds via additional compromised machines running implant malware, as well as targeting for quick exfiltration the key data they came for.\n\nSponsor type and motivation\n\nSponsor: State-sponsored, PLA Unit 61398', metadata={'source': 'documents/Operation Shady RAT/Operation_Shady_RAT.md'}),
#   Document(page_content='Threat actor: Operation Shady RAT\n\nUUID: 3227cd76-90c0-4139-83c0-afbdb298d1f2\n\nFirst seen: 2006\n\nSource last modified: 2021-05-21\n\nThreat actor aliases\n\nOperation Shady RAT (McAfee)\n\nDescription\n\n(McAfee) With the goal of raising the level of public awareness today we are publishing the most comprehensive analysis ever revealed of victim profiles from a five year targeted operation by one specific actor—Operation Shady RAT, as I have named it at McAfee (RAT is a common acronym in the industry which stands for Remote Access Tool).\n\nThis is not a new attack, and the vast majority of the victims have long since remediated these specific infections (although whether most realized the seriousness of the intrusion or simply cleaned up the infected machine without further analysis into the data loss is an open question). McAfee has detected the malware variants and other relevant indicators for years with Generic Downloader.x and Generic BackDoor.t heuristic signatures (those who have had prior experience with this specific adversary may recognize it by the use of encrypted HTML comments in web pages that serve as a command channel to the infected machine).\n\nMcAfee has gained access to one specific Command & Control server used by the intruders. We have collected logs that reveal the full extent of the victim population since mid-2006 when the log collection began. Note that the actual intrusion activity may have begun well before that time but that is the earliest evidence we have for the start of the compromises. The compromises themselves were standard procedure for these types of targeted intrusions: a spear-phishing email containing an exploit is sent to an individual with the right level of access at the company, and the exploit when opened on an unpatched system will trigger a download of the implant malware. That malware will execute and initiate a backdoor communication channel to the Command & Control web server and interpret the instructions encoded in the hidden comments embedded in the webpage code. This will be quickly followed by live intruders jumping on to the infected machine and proceeding to quickly escalate privileges and move laterally within the organization to establish new persistent footholds via additional compromised machines running implant malware, as well as targeting for quick exfiltration the key data they came for.\n\nSponsor type and motivation\n\nSponsor: State-sponsored, PLA Unit 61398', metadata={'source': 'documents/Operation Shady RAT/Operation_Shady_RAT.md'}),
#   Document(page_content='Perhaps the most predominant attack we researched in this quarter was the SolarWinds attack. SolarWinds showed once again how successful a supply-chain attack can be, especially where attackers go the extra mile to remain hidden and maintain persistence in a target network. The scope of this attack is still being investigated as more zero-day flaws are discovered in SolarWinds products.\nAnother critical wave of attacks was the exploitation of Microsoft Exchange zero-day vulnerabilities by multiple threat actors. We recently discovered another campaign using these exploits with different targeting, possibly related to the same cluster of activities already reported.\nLazarus group’s bold campaign targeting security researchers worldwide also utilized zero-day vulnerabilities in browsers to compromise their targets. Their campaigns used themes centered on the use of zero-days to lure relevant researchers, possibly in an attempt to steal vulnerability research.\n\nAs always, we would note that our reports are the product of our visibility into the threat landscape. However, it should be borne in mind that, while we strive to continually improve, there is always the possibility that other sophisticated attacks may fly under our radar.\n\nAPT\nChinese-speaking cybercrime\nLazarus\nMalware Technologies\nMicrosoft\nMuddyWater\nRussian-speaking cybercrime\nSpyware\nSunburst\nTargeted attacks\nTurla\nVulnerabilities and exploits\nZero-day vulnerabilities\n\nAuthors\n\nGReAT\n\nAPT trends report Q1 2021 \n Your email address will not be published. Required fields are marked *Name * \nEmail *\n\nCancel\n\njackd\n\ngreat  great\nReply\n\nTable of Contents\n\nThe most remarkable findingsEuropeRussian-speaking activityChinese-speaking activityMiddle EastSoutheast Asia and Korean PeninsulaOther interesting discoveriesFinal thoughts\n\nGReAT webinars\n\nGReAT Ideas. Balalaika Edition\n\nBoris Larin\n\nDenis Legezo\n\nGReAT Ideas. Green Tea Edition\n\nJohn Hultquist\n\nBrian Bartholomew\n\nSuguru Ishimaru\n\nVitaly Kamluk\n\nSeongsu Park\n\nYusuke Niwa\n\nMotohiko Sato\n\nGReAT Ideas. Powered by SAS: malware attribution and next-gen IoT honeypots\n\nMarco Preuss\n\nDenis Legezo\n\nCostin Raiu\n\nKurt Baumgartner\n\nDan Demeter\n\nYaroslav Shmelev\n\nGReAT Ideas. Powered by SAS: threat actors advance on new fronts\n\nIvan Kwiatkowski\n\nMaher Yamout', metadata={'source': 'documents/Karkadann/APT_trends_report_Q1_2021_|_Securelist.md'})],
#  'question': 'Describe vulnerabilities that threat actor cl0p has exploited throughout various campaigns.',
#  'answer': 'Cl0p has exploited vulnerabilities in Internet Explorer versions 9 through 11, targeting organizations in various industries through phishing campaigns. The threat actor has leveraged multiple exploits, including CVE-2014-6332 and CVE-2014-4113, to target multiple organizations in their campaigns. Cl0p has also used social networking as a vector to target victims in their operations.'}
