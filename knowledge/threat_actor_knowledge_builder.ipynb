# %% [markdown]
# # Threat Actor Knowledge Source Knowledge Building - ETDA Database
# This notebook is heavily inspired by the excellent research of Roberto Rodriguez (@Cyb3rWard0g) into the applicability of generative AI for threat intelligence purposes. It follows the same structure with small alterations for this specific use case.
#
# In specific, this notebook describes how to build a threat actor source knowledge vector database based on the ETDA threat actor database and its linked reports. We collect all the URLs and scrape the reports per threat actor. PDFs are currently not parsed. For data cleaning, we only remove some of the failed retrievals for now. We save these as markdown documents, after which we decompose the information into chunks and embed them in a Chroma vector database.
#
#
# References:
#
# - https://blog.openthreatresearch.com/demystifying-generative-ai-a-security-researchers-notes/
# - https://github.com/OTRF/GenAI-Security-Adventures
# - https://github.com/OTRF/GenAI-Security-Adventures/blob/main/experiments/RAG/Threat-Intelligence/ATTCK-Groups/source-knowledge/notebook.ipynb
# - https://python.langchain.com/docs/get_started/introduction
# - https://apt.etda.or.th/cgi-bin/aptgroups.cgi

# %% [markdown]
# # Improvement ideas
# - [ ] Clean scraped data from failed loads
# - [ ] Clean scraped data from irrelevant context (other webpage content)
# - [ ] Integrate PDF scraping and parsing
# - [ ] Add other threat actor information sources
# - [ ] Create summaries of reports for more condensed context
# - [ ] Experiment with other chunk sizes

# %% [markdown]
# # Import modules

# %%
import os
import glob
import openai
import tiktoken
import tqdm as notebook_tqdm
import urllib.request, json
import copy
import hashlib
import nest_asyncio
import tqdm as notebook_tqdm
from jsonpath_ng import jsonpath, parse
from dotenv import load_dotenv
from langchain.text_splitter import RecursiveCharacterTextSplitter
from jinja2 import Template
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.vectorstores import Chroma
from langchain.document_loaders import WebBaseLoader
from langchain.document_loaders import UnstructuredMarkdownLoader

# %% [markdown]
# # Define initial variables and OpenAI API key

# %%
load_dotenv()
# Get your key: https://platform.openai.com/account/api-keys
openai.api_key = os.getenv("OPENAI_API_KEY")
chroma_db = os.path.join(current_directory, "./knowledge/chroma_db")

current_directory = os.path.dirname("__file__")
documents_directory = os.path.join(current_directory, "documents")
reports_directory = os.path.join(documents_directory, "reports")
contrib_directory = os.path.join(current_directory, "contrib")
embeddings_directory = os.path.join(current_directory, "embeddings")
templates_directory = os.path.join(current_directory, "templates")
document_template = os.path.join(templates_directory, "document.md")
group_template = os.path.join(templates_directory, "group.md")

# %% [markdown]
# # Load ETDA threat actor database
# Get JSON to laod reports per threat actor from. We distinguish between activity reports (operations) and information reports.

# %%
with urllib.request.urlopen("https://apt.etda.or.th/cgi-bin/getcard.cgi?g=all&o=j") as url:
    data = json.load(url)

# parse just threat actor activity reports, information references, and MITRE pages
activity_query = parse('$..activity')
information_query = parse('$..information[*]')

activity_data = activity_query.find(data)
information_data = information_query.find(data)

# split every activity report into an array of lines (split based on new line) to extract URL
activity_lines = [line.value.split('\n') for line in activity_data];

# parse just URLs from all the lines, which are last if included
activity_urls = [subarray[-1] for subarray in activity_lines]
information_urls = [url.value for url in information_data]

# dismiss any non-URLs and get web reports. we collect PDF reports seperately
information_urls_cleaned = [item for item in information_urls if not "pdf" in item]
information_pdfs = [item for item in information_urls if "pdf" in item]
activity_urls_cleaned = [item for item in activity_urls if "http" in item and not "pdf" in item]
activity_pdfs = [item for item in activity_urls if "http" in item and "pdf" in item]

print(f"loaded threat actor documents: {len(activity_urls_cleaned)} activity web reports")
print(f"loaded threat actor documents: {len(activity_pdfs)} activity pdf reports (unused)")
print(f"loaded threat actor documents: {len(information_urls_cleaned)} information references")
print(f"loaded threat actor documents: {len(information_pdfs)} information pdf references (unused)")
# Out:
# loaded threat actor documents: 2118 activity web reports
# loaded threat actor documents: 109 activity pdf reports (unused)
# loaded threat actor documents: 783 information references
# loaded threat actor documents: 183 information pdf references (unused)

# %% [markdown]
# # Scrape reports
# Use Langchain webbaseloader in multithreaded fashion.

# %%
# fixes a bug with asyncio and jupyter
nest_asyncio.apply()

all_urls = activity_urls_cleaned + information_urls_cleaned
loader = WebBaseLoader(all_urls, continue_on_failure=True)

# don't verify SSL connections
loader.requests_kwargs = {'verify':False}

loader.requests_per_second = 50

docs = loader.aload()
print(f"successfully loaded threat actor documents: {len(docs)} documents")
# Out:
# Fetching pages:   3%|##5                                                                                 | 87/2901 [00:13<08:08,  5.76it/s]Error fetching https://mycryptomag.com/2019/08/08/cryptocurrency-firms-are-targets-of-state-sponsored-hacking-group-from-china/ with attempt 1/3: Cannot connect to host mycryptomag.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:   3%|##7                                                                                 | 96/2901 [00:18<11:36,  4.03it/s]Error fetching https://mycryptomag.com/2019/08/08/cryptocurrency-firms-are-targets-of-state-sponsored-hacking-group-from-china/ with attempt 2/3: Cannot connect to host mycryptomag.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:   5%|####5                                                                              | 158/2901 [00:33<11:58,  3.82it/s]Error fetching https://mycryptomag.com/2019/08/08/cryptocurrency-firms-are-targets-of-state-sponsored-hacking-group-from-china/, skipping due to continue_on_failure=True
# Fetching pages:   8%|######3                                                                            | 222/2901 [00:47<08:42,  5.13it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/ with attempt 1/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Fetching pages:   9%|#######                                                                            | 248/2901 [00:48<05:13,  8.47it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/ with attempt 2/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/, skipping due to continue_on_failure=True
# Fetching pages:  10%|########4                                                                          | 297/2901 [00:54<05:04,  8.55it/s]Error fetching https://ti.dbappsecurity.com.cn/blog/index.php/2021/02/10/windows-kernel-zero-day-exploit-is-used-by-bitter-apt-in-targeted-attack/, skipping due to continue_on_failure=True
# Fetching pages:  15%|############3                                                                      | 430/2901 [01:15<06:28,  6.35it/s]Error fetching https://www.phnompenhpost.com/national/kingdom-targeted-new-malware with attempt 1/3: Cannot connect to host www.phnompenhpost.com:443 ssl:default [Connect call failed ('::', 443, 0, 0)]. Retrying...
# Fetching pages:  15%|############5                                                                      | 438/2901 [01:18<08:26,  4.87it/s]Error fetching https://ssu.gov.ua/sbu/control/uk/publish/article?art_id=170951&cat_id=39574 with attempt 1/3: Cannot connect to host ssu.gov.ua:443 ssl:default [Connection reset by peer]. Retrying...
# Error fetching https://threatrecon.nshc.net/2019/08/02/sectore02-updates-yty-framework-in-new-targeted-campaign-against-pakistan-government/ with attempt 1/3: Cannot connect to host threatrecon.nshc.net:443 ssl:default [Connect call failed ('2600:9000:2447:d200:c:dae6:cc0:93a1', 443, 0, 0)]. Retrying...
# Fetching pages:  16%|#############3                                                                     | 467/2901 [01:19<04:45,  8.53it/s]Error fetching https://www.phnompenhpost.com/national/kingdom-targeted-new-malware with attempt 2/3: Cannot connect to host www.phnompenhpost.com:443 ssl:default [Connect call failed ('0.0.0.0', 443)]. Retrying...
# Error fetching https://ssu.gov.ua/sbu/control/uk/publish/article?art_id=170951&cat_id=39574 with attempt 2/3: Cannot connect to host ssu.gov.ua:443 ssl:default [Connection reset by peer]. Retrying...
# Error fetching https://threatrecon.nshc.net/2019/08/02/sectore02-updates-yty-framework-in-new-targeted-campaign-against-pakistan-government/ with attempt 2/3: Cannot connect to host threatrecon.nshc.net:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')]. Retrying...
# Error fetching https://www.phnompenhpost.com/national/kingdom-targeted-new-malware, skipping due to continue_on_failure=True
# Fetching pages:  17%|#############7                                                                     | 479/2901 [01:24<06:57,  5.81it/s]Error fetching https://ssu.gov.ua/sbu/control/uk/publish/article?art_id=170951&cat_id=39574, skipping due to continue_on_failure=True
# Error fetching https://threatrecon.nshc.net/2019/08/02/sectore02-updates-yty-framework-in-new-targeted-campaign-against-pakistan-government/, skipping due to continue_on_failure=True
# Fetching pages:  20%|################8                                                                  | 589/2901 [01:31<03:12, 12.04it/s]Error fetching https://blog.bit9.com/2013/02/08/bit9-and-our-customers-security/ with attempt 1/3: Cannot connect to host blog.bit9.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  22%|##################5                                                                | 649/2901 [01:33<02:07, 17.64it/s]Error fetching https://www.nccgroup.trust/uk/about-us/newsroom-and-events/blogs/2018/march/apt15-is-alive-and-strong-an-analysis-of-royalcli-and-royaldns/ with attempt 1/3: Cannot connect to host www.nccgroup.trust:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://atr-blog.gigamon.com/2019/07/23/abadbabe-8badf00d:-discovering-badhatch-and-a-detailed-look-at-fin8’s-tooling/ with attempt 1/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://blog.bit9.com/2013/02/08/bit9-and-our-customers-security/ with attempt 2/3: Cannot connect to host blog.bit9.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  24%|####################                                                               | 701/2901 [01:35<01:46, 20.70it/s]Error fetching https://www.nccgroup.trust/uk/about-us/newsroom-and-events/blogs/2018/march/apt15-is-alive-and-strong-an-analysis-of-royalcli-and-royaldns/ with attempt 2/3: Cannot connect to host www.nccgroup.trust:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://atr-blog.gigamon.com/2019/07/23/abadbabe-8badf00d:-discovering-badhatch-and-a-detailed-look-at-fin8’s-tooling/ with attempt 2/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://blog.bit9.com/2013/02/08/bit9-and-our-customers-security/, skipping due to continue_on_failure=True
# Fetching pages:  26%|#####################3                                                             | 745/2901 [01:44<04:28,  8.04it/s]Error fetching https://atr-blog.gigamon.com/2019/07/23/abadbabe-8badf00d:-discovering-badhatch-and-a-detailed-look-at-fin8’s-tooling/, skipping due to continue_on_failure=True
# Fetching pages:  26%|#####################7                                                             | 760/2901 [01:46<04:22,  8.15it/s]Error fetching https://www.nccgroup.trust/uk/about-us/newsroom-and-events/blogs/2018/march/apt15-is-alive-and-strong-an-analysis-of-royalcli-and-royaldns/, skipping due to continue_on_failure=True
# Error fetching <https://www.microsoft.com/en-us/security/blog/2023/10/18/multiple-north-korean-threat-actors-exploiting-the-teamcity-cve-2023-42793-vulnerability/, skipping due to continue_on_failure=True
# Fetching pages:  39%|###############################5                                                  | 1117/2901 [02:11<01:17, 22.95it/s]Error fetching https://content.fireeye.com/web-assets/rpt-unc1151-ghostwriter-update with attempt 1/3: Cannot connect to host content.fireeye.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'content.fireeye.com'. (_ssl.c:1129)")]. Retrying...
# Fetching pages:  40%|################################9                                                 | 1166/2901 [02:12<01:00, 28.87it/s]Error fetching https://ti.dbappsecurity.com.cn/blog/index.php/2020/09/18/operation-domino/, skipping due to continue_on_failure=True
# Fetching pages:  41%|#################################9                                                | 1200/2901 [02:15<01:16, 22.21it/s]Error fetching https://content.fireeye.com/web-assets/rpt-unc1151-ghostwriter-update with attempt 2/3: Cannot connect to host content.fireeye.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'content.fireeye.com'. (_ssl.c:1129)")]. Retrying...
# Fetching pages:  44%|####################################2                                             | 1281/2901 [02:18<01:06, 24.20it/s]Error fetching https://content.fireeye.com/web-assets/rpt-unc1151-ghostwriter-update, skipping due to continue_on_failure=True
# Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/first-active-attack-exploiting-cve-2019-2215-found-on-google-play-linked-to-sidewinder-apt-group/ with attempt 1/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Fetching pages:  47%|######################################6                                           | 1368/2901 [02:21<00:51, 29.66it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/first-active-attack-exploiting-cve-2019-2215-found-on-google-play-linked-to-sidewinder-apt-group/ with attempt 2/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Fetching pages:  50%|########################################5                                         | 1436/2901 [02:23<00:49, 29.30it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/first-active-attack-exploiting-cve-2019-2215-found-on-google-play-linked-to-sidewinder-apt-group/, skipping due to continue_on_failure=True
# Fetching pages:  61%|##################################################1                               | 1773/2901 [02:35<00:37, 30.24it/s]Error fetching https://www.advintel.io/post/the-trickbot-saga-s-finale-has-aired-but-a-spinoff-is-already-in-the-works with attempt 1/3: Cannot connect to host www.advintel.io:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')]. Retrying...
# Fetching pages:  62%|###################################################                               | 1806/2901 [02:37<00:44, 24.59it/s]Error fetching https://www.advintel.io/post/the-trickbot-saga-s-finale-has-aired-but-a-spinoff-is-already-in-the-works with attempt 2/3: Cannot connect to host www.advintel.io:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')]. Retrying...
# Fetching pages:  68%|#######################################################9                          | 1979/2901 [02:40<00:23, 38.80it/s]Error fetching https://www.advintel.io/post/the-trickbot-saga-s-finale-has-aired-but-a-spinoff-is-already-in-the-works, skipping due to continue_on_failure=True
# Fetching pages:  70%|#########################################################1                        | 2022/2901 [02:43<00:29, 30.02it/s]Error fetching https://musalbas.com/blog/2016/08/16/equation-group-firewall-operations-catalogue.html with attempt 1/3: Cannot connect to host musalbas.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://www.scmagazineuk.com/second-shadow-brokers-dump-released/article/1476023 with attempt 1/3: Cannot connect to host www.scmagazineuk.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')]. Retrying...
# Fetching pages:  71%|##########################################################1                       | 2058/2901 [02:44<00:30, 27.64it/s]Error fetching https://musalbas.com/blog/2016/08/16/equation-group-firewall-operations-catalogue.html with attempt 2/3: Cannot connect to host musalbas.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://www.scmagazineuk.com/second-shadow-brokers-dump-released/article/1476023 with attempt 2/3: Cannot connect to host www.scmagazineuk.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')]. Retrying...
# Fetching pages:  74%|############################################################4                     | 2139/2901 [02:46<00:23, 32.62it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/ with attempt 1/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Fetching pages:  75%|#############################################################4                    | 2175/2901 [02:47<00:21, 33.29it/s]Error fetching https://www.mandiant.com/media/17826, skipping due to continue_on_failure=True
# Error fetching https://musalbas.com/blog/2016/08/16/equation-group-firewall-operations-catalogue.html, skipping due to continue_on_failure=True
# Error fetching https://www.scmagazineuk.com/second-shadow-brokers-dump-released/article/1476023, skipping due to continue_on_failure=True
# Fetching pages:  76%|##############################################################4                   | 2211/2901 [02:48<00:20, 32.93it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/ with attempt 2/3: Cannot connect to host 127.0.0.1:80 ssl:default [Connect call failed ('127.0.0.1', 80)]. Retrying...
# Error fetching http://blog.ptsecurity.com/2019/11/studying-donot-team.html with attempt 1/3: Cannot connect to host blog.ptsecurity.com:80 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  77%|###############################################################4                  | 2246/2901 [02:49<00:19, 33.04it/s]Error fetching https://atr-blog.gigamon.com/2017/07/25/footprints-of-fin7-tracking-actor-patterns-part-1 with attempt 1/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://atr-blog.gigamon.com/2017/07/26/footprints-of-fin7-tracking-actor-patterns-part-2 with attempt 1/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching http://blog.ptsecurity.com/2019/11/studying-donot-team.html with attempt 2/3: Cannot connect to host blog.ptsecurity.com:80 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  79%|################################################################4                 | 2281/2901 [02:51<00:23, 26.48it/s]Error fetching https://blog.trendmicro.com/trendlabs-security-intelligence/following-trail-blacktech-cyber-espionage-campaigns/, skipping due to continue_on_failure=True
# Fetching pages:  80%|#################################################################8                | 2330/2901 [02:53<00:18, 31.19it/s]Error fetching https://www.mandiant.com/media/12596/download, skipping due to continue_on_failure=True
# Error fetching https://atr-blog.gigamon.com/2017/07/25/footprints-of-fin7-tracking-actor-patterns-part-1 with attempt 2/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://atr-blog.gigamon.com/2017/07/26/footprints-of-fin7-tracking-actor-patterns-part-2 with attempt 2/3: Cannot connect to host atr-blog.gigamon.com:443 ssl:default [Name or service not known]. Retrying...
# Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/ with attempt 1/3: Cannot connect to host public.intel471.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  82%|##################################################################8               | 2365/2901 [02:54<00:17, 31.29it/s]Error fetching https://content.fireeye.com/apt/rpt-apt38 with attempt 1/3: Cannot connect to host content.fireeye.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'content.fireeye.com'. (_ssl.c:1129)")]. Retrying...
# Error fetching http://blog.ptsecurity.com/2019/11/studying-donot-team.html, skipping due to continue_on_failure=True
# Fetching pages:  83%|####################################################################              | 2406/2901 [02:55<00:14, 33.74it/s]Error fetching https://eng.nis.go.kr/common/download.do?type=&seq=8E464392CD0485169FA97278AEE8B607 with attempt 1/3: Cannot connect to host eng.nis.go.kr:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')]. Retrying...
# Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/ with attempt 2/3: Cannot connect to host public.intel471.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  84%|#####################################################################2            | 2451/2901 [02:56<00:12, 36.58it/s]Error fetching https://www.prevailion.com/diving-deep-into-unc1151s-infrastructure-ghostwriter-and-beyond/ with attempt 1/3: Cannot connect to host www.prevailion.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.prevailion.com'. (_ssl.c:1129)")]. Retrying...
# Error fetching https://atr-blog.gigamon.com/2017/07/25/footprints-of-fin7-tracking-actor-patterns-part-1, skipping due to continue_on_failure=True
# Error fetching https://atr-blog.gigamon.com/2017/07/26/footprints-of-fin7-tracking-actor-patterns-part-2, skipping due to continue_on_failure=True
# Error fetching https://content.fireeye.com/apt/rpt-apt38 with attempt 2/3: Cannot connect to host content.fireeye.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'content.fireeye.com'. (_ssl.c:1129)")]. Retrying...
# Error fetching https://eng.nis.go.kr/common/download.do?type=&seq=8E464392CD0485169FA97278AEE8B607 with attempt 2/3: Cannot connect to host eng.nis.go.kr:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')]. Retrying...
# Error fetching https://www.prevailion.com/diving-deep-into-unc1151s-infrastructure-ghostwriter-and-beyond/ with attempt 2/3: Cannot connect to host www.prevailion.com:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.prevailion.com'. (_ssl.c:1129)")]. Retrying...
# Fetching pages:  86%|######################################################################3           | 2490/2901 [02:58<00:16, 25.00it/s]Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/, skipping due to continue_on_failure=True
# Fetching pages:  89%|#########################################################################2        | 2591/2901 [03:00<00:08, 35.62it/s]Error fetching https://content.fireeye.com/apt/rpt-apt38, skipping due to continue_on_failure=True
# Error fetching https://eng.nis.go.kr/common/download.do?type=&seq=8E464392CD0485169FA97278AEE8B607, skipping due to continue_on_failure=True
# Error fetching https://www.prevailion.com/diving-deep-into-unc1151s-infrastructure-ghostwriter-and-beyond/, skipping due to continue_on_failure=True
# Fetching pages:  91%|##########################################################################4       | 2633/2901 [03:01<00:07, 36.84it/s]Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/ with attempt 1/3: Cannot connect to host public.intel471.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  92%|###########################################################################6      | 2678/2901 [03:03<00:05, 38.45it/s]Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/ with attempt 2/3: Cannot connect to host public.intel471.com:443 ssl:default [Name or service not known]. Retrying...
# Fetching pages:  97%|###############################################################################6  | 2819/2901 [03:06<00:01, 43.08it/s]Error fetching https://h3collective.io/review-of-a-danabot-infection/ with attempt 1/3: Cannot connect to host h3collective.io:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')]. Retrying...
# Error fetching https://public.intel471.com/blog/partners-in-crime-north-koreans-and-elite-russian-speaking-cybercriminals/, skipping due to continue_on_failure=True
# Fetching pages:  99%|################################################################################9 | 2864/2901 [03:07<00:01, 35.56it/s]Error fetching https://h3collective.io/review-of-a-danabot-infection/ with attempt 2/3: Cannot connect to host h3collective.io:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')]. Retrying...
# Error fetching https://www.netformation.com/our-pov/casting-light-on-the-necurs-shadow/ with attempt 1/3: Cannot connect to host www.netformation.com:443 ssl:default [Connect call failed ('8.238.178.126', 443)]. Retrying...
# Error fetching https://h3collective.io/review-of-a-danabot-infection/, skipping due to continue_on_failure=True
# Error fetching https://www.netformation.com/our-pov/casting-light-on-the-necurs-shadow/ with attempt 2/3: Cannot connect to host www.netformation.com:443 ssl:default [Connect call failed ('8.247.210.126', 443)]. Retrying...
# Error fetching https://lab52.io/blog/new-mustang-pandas-campaing-against-australia/ with attempt 1/3: Cannot connect to host lab52.io:443 ssl:default [None]. Retrying...
# Error fetching https://www.netformation.com/our-pov/casting-light-on-the-necurs-shadow/, skipping due to continue_on_failure=True
# Fetching pages:  99%|################################################################################9 | 2864/2901 [03:22<00:01, 35.56it/s]Error fetching http://blogs.360.cn/post/APT_Darkhotel_attacks_during_coronavirus_pandemic.html with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching https://shadownet.co.za/2019/07/01/locky-ransomware-is-back-in-a-big-way/ with attempt 1/3: Cannot connect to host shadownet.co.za:443 ssl:default [None]. Retrying...
# Error fetching https://lab52.io/blog/wirte-group-attacking-the-middle-east/ with attempt 1/3: Cannot connect to host lab52.io:443 ssl:default [None]. Retrying...
# Error fetching https://shadownet.co.za/2019/07/01/locky-ransomware-is-back-in-a-big-way/ with attempt 2/3: Cannot connect to host shadownet.co.za:443 ssl:default [None]. Retrying...
# Error fetching http://blogs.360.cn/post/APT-C-39_CIA_EN.html with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching https://cyberx-labs.com/blog/gangnam-industrial-style-apt-campaign-targets-korean-industrial-companies/ with attempt 1/3: Cannot connect to host cyberx-labs.com:443 ssl:default [Connect call failed ('35.209.118.24', 443)]. Retrying...
# Error fetching https://lab52.io/blog/wirte-group-attacking-the-middle-east/ with attempt 2/3: Cannot connect to host lab52.io:443 ssl:default [None]. Retrying...
# Error fetching https://cyberx-labs.com/blog/operation-bugdrop-cyberx-discovers-large-scale-cyber-reconnaissance-operation/ with attempt 1/3: Cannot connect to host cyberx-labs.com:443 ssl:default [Connect call failed ('35.209.118.24', 443)]. Retrying...
# Error fetching http://blogs.360.cn/post/PoisonNeedles_CVE-2018-15982_EN with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Fetching pages: 100%|#################################################################################7| 2892/2901 [05:10<00:08,  1.08it/s]Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 1/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/APT_Darkhotel_attacks_during_coronavirus_pandemic.html with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching https://shadownet.co.za/2019/07/01/locky-ransomware-is-back-in-a-big-way/, skipping due to continue_on_failure=True
# Fetching pages: 100%|#################################################################################7| 2893/2901 [05:44<00:10,  1.26s/it]Error fetching http://blogs.360.cn/post/APT-C-39_CIA_EN.html with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching https://cyberx-labs.com/blog/gangnam-industrial-style-apt-campaign-targets-korean-industrial-companies/ with attempt 2/3: Cannot connect to host cyberx-labs.com:443 ssl:default [Connect call failed ('35.209.118.24', 443)]. Retrying...
# Error fetching http://blogs.360.cn/post/PoisonNeedles_CVE-2018-15982_EN with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching https://cyberx-labs.com/blog/operation-bugdrop-cyberx-discovers-large-scale-cyber-reconnaissance-operation/ with attempt 2/3: Cannot connect to host cyberx-labs.com:443 ssl:default [Connect call failed ('35.209.118.24', 443)]. Retrying...
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html with attempt 2/3: Cannot connect to host blogs.360.cn:80 ssl:default [Connect call failed ('106.120.161.225', 80)]. Retrying...
# Error fetching http://blogs.360.cn/post/APT_Darkhotel_attacks_during_coronavirus_pandemic.html, skipping due to continue_on_failure=True
# Fetching pages: 100%|#################################################################################8| 2894/2901 [08:01<00:22,  3.25s/it]Error fetching http://blogs.360.cn/post/APT-C-39_CIA_EN.html, skipping due to continue_on_failure=True
# Fetching pages: 100%|#################################################################################8| 2895/2901 [09:36<00:30,  5.11s/it]Error fetching https://cyberx-labs.com/blog/gangnam-industrial-style-apt-campaign-targets-korean-industrial-companies/, skipping due to continue_on_failure=True
# Fetching pages: 100%|#################################################################################8| 2896/2901 [09:40<00:25,  5.08s/it]Error fetching https://cyberx-labs.com/blog/operation-bugdrop-cyberx-discovers-large-scale-cyber-reconnaissance-operation/, skipping due to continue_on_failure=True
# Error fetching http://blogs.360.cn/post/PoisonNeedles_CVE-2018-15982_EN, skipping due to continue_on_failure=True
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html, skipping due to continue_on_failure=True
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html, skipping due to continue_on_failure=True
# Error fetching http://blogs.360.cn/post/SEA_role_influence_cyberattacks.html, skipping due to continue_on_failure=True
# Fetching pages: 100%|##################################################################################| 2901/2901 [09:48<00:00,  4.93it/s]
# successfully loaded threat actor documents: 2901 documents

# %% [markdown]
# # Clean the data
# Remove reports that are short in length.

# %%
# remove documents with almost no text
for index, doc in enumerate(docs):
    if (len(doc.page_content) < 100):
        print(f"removing document {index}")
        docs.pop(index)

print(f"leftover loaded threat actor documents after filtering: {len(docs)} documents")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # remove documents with almost no text
# ----> 2 for index, doc in enumerate(docs):
#       3     if (len(doc.page_content) < 100):
#       4         print(f"removing document {index}")
#
# NameError: name 'docs' is not defined

# %% [markdown]
# # Create threat actor Markdown docs

# %%
if not os.path.exists(documents_directory):
   print("[+] Creating knowledge directory..")
   os.makedirs(documents_directory)

if not os.path.exists(reports_directory):
   print("[+] Creating reports directory..")
   os.makedirs(reports_directory)

print("[+] Creating markdown files for each group..")
markdown_group_template = Template(open(group_template).read())
markdown_document_template = Template(open(document_template).read())
for group in data['values']:
    if not os.path.exists(os.path.join(reports_directory, group['actor'].replace('/','_'))):
       print("  [>>] Creating folder for {}..".format(group['actor']))
       os.makedirs(os.path.join(reports_directory, group['actor'].replace('/','_')))
        
    print("  [>>] Creating markdown files for {}..".format(group['actor']))
    group_for_render = copy.deepcopy(group)
    
    # create threat actor metadata document
    markdown_group = markdown_group_template.render(metadata=group_for_render)
    file_name = (group['actor']).replace(' ','_').replace('/','_')
    open(f'{reports_directory}/{group["actor"].replace("/","_")}/{file_name}.md', encoding='utf-8', mode='w').write(markdown_group)

    # create threat actor information documents
    if 'information' in group:
        for information in group['information']:
            matches = [copy.deepcopy(doc) for doc in docs if doc.metadata['source'] == information]
            for match in matches:
                markdown_information = markdown_document_template.render(metadata=match.metadata, group_name=group['actor'], page_content=match.page_content)
                file_name = (match.metadata['title']).replace(' ','_').replace('/','_')
                open(f'{reports_directory}/{group["actor"].replace("/","_")}/{file_name}.md', encoding='utf-8', mode='w').write(markdown_information)

    # create threat actor activity reports
    if 'operations' in group:
        for activity in group['operations']:
            matches = [copy.deepcopy(doc) for doc in docs if doc.metadata['source'] in activity['activity']]
            for index, match in enumerate(matches):
                markdown_information = markdown_document_template.render(metadata=match.metadata, group_name=group['actor'], page_content=match.page_content)
                if 'title' in match.metadata:
                    file_name = (match.metadata['title']).replace(' ','_').replace('/','_')
                else:
                    file_name = "Report " + str(index)
                open(f'{reports_directory}/{group["actor"].replace("/","_")}/{file_name}.md', encoding='utf-8', mode='w').write(markdown_information)
# Out:
# [+] Creating markdown files for each group..
#   [>>] Creating markdown files for Big Panda..
#   [>>] Creating markdown files for Boulder Bear..
#   [>>] Creating markdown files for Clockwork Spider..
#   [>>] Creating markdown files for Corsair Jackal..
#   [>>] Creating markdown files for Dextorous Spider..
#   [>>] Creating markdown files for Dizzy Panda..
#   [>>] Creating markdown files for Electric Panda..
#   [>>] Creating markdown files for Eloquent Panda..
#   [>>] Creating markdown files for Flyfox..
#   [>>] Creating markdown files for Foxy Panda..
#   [>>] Creating markdown files for Ghost Jackal..
#   [>>] Creating markdown files for Gibberish Panda..
#   [>>] Creating markdown files for HolyWater..
#   [>>] Creating markdown files for Impersonating Panda..
#   [>>] Creating markdown files for Knockout Spider..
#   [>>] Creating markdown files for Kumsong121..
#   [>>] Creating markdown files for Magnetic Spider..
#   [>>] Creating markdown files for Outlaw Spider..
#   [>>] Creating markdown files for Overlord Spider..
#   [>>] Creating markdown files for Pale Panda..
#   [>>] Creating markdown files for ParkingBear..
#   [>>] Creating markdown files for Poisonous Panda..
#   [>>] Creating markdown files for Predator Panda..
#   [>>] Creating markdown files for Sabre Panda..
#   [>>] Creating markdown files for Singing Spider..
#   [>>] Creating markdown files for Solar Spider..
#   [>>] Creating markdown files for Spicy Panda..
#   [>>] Creating markdown files for Test Panda..
#   [>>] Creating markdown files for Toxic Panda..
#   [>>] Creating markdown files for Union Panda..
#   [>>] Creating markdown files for Union Spider..
#   [>>] Creating markdown files for Viking Jackal..
#   [>>] Creating markdown files for Wet Panda..
#   [>>] Creating markdown files for AeroBlade..
#   [>>] Creating markdown files for Aggah..
#   [>>] Creating markdown files for Agrius..
#   [>>] Creating markdown files for Allanite..
#   [>>] Creating markdown files for ALPHV, BlackCat Gang..
#   [>>] Creating markdown files for Scattered Spider..
#   [>>] Creating markdown files for Anchor Panda, APT 14..
#   [>>] Creating markdown files for Antlion..
#   [>>] Creating markdown files for Aoqin Dragon..
#   [>>] Creating markdown files for APT 3, Gothic Panda, Buckeye..
#   [>>] Creating markdown files for APT 4, Maverick Panda, Wisp Team..
#   [>>] Creating markdown files for APT 5, Keyhole Panda..
#   [>>] Creating markdown files for APT 6..
#   [>>] Creating markdown files for APT 12, Numbered Panda..
#   [>>] Creating markdown files for APT 16, SVCMONDR..
#   [>>] Creating markdown files for APT 17, Deputy Dog, Elderwood, Sneaky Panda..
#   [>>] Creating markdown files for APT 18, Dynamite Panda, Wekby..
#   [>>] Creating markdown files for APT 19, Deep Panda, C0d0so0..
#   [>>] Creating markdown files for APT 20, Violin Panda..
#   [>>] Creating markdown files for APT 29, Cozy Bear, The Dukes..
#   [>>] Creating markdown files for APT 30, Override Panda..
#   [>>] Creating markdown files for APT 31, Judgment Panda, Zirconium..
#   [>>] Creating markdown files for APT 32, OceanLotus, SeaLotus..
#   [>>] Creating markdown files for APT 33, Elfin, Magnallium..
#   [>>] Creating markdown files for APT 41..
#   [>>] Creating markdown files for Earth Longzhi..
#   [>>] Creating markdown files for APT 42..
#   [>>] Creating markdown files for Aquatic Panda..
#   [>>] Creating markdown files for AtlasCross..
#   [>>] Creating markdown files for AVIVORE..
#   [>>] Creating markdown files for Axiom, Group 72..
#   [>>] Creating markdown files for Bad Magic, RedStinger..
#   [>>] Creating markdown files for Bahamut..
#   [>>] Creating markdown files for Barium..
#   [>>] Creating markdown files for Berserk Bear, Dragonfly 2.0..
#   [>>] Creating markdown files for The Big Bang..
#   [>>] Creating markdown files for Bitter..
#   [>>] Creating markdown files for Blackgear..
#   [>>] Creating markdown files for BlackOasis..
#   [>>] Creating markdown files for BlackTech, Circuit Panda, Radio Panda..
#   [>>] Creating markdown files for Blind Eagle..
#   [>>] Creating markdown files for Blue Termite, Cloudy Omega..
#   [>>] Creating markdown files for Bookworm..
#   [>>] Creating markdown files for Boss Spider, Gold Lowell..
#   [>>] Creating markdown files for Bronze Butler, Tick, RedBaldNight, Stalker Panda..
#   [>>] Creating markdown files for Bronze Highland..
#   [>>] Creating markdown files for Bronze Starlight..
#   [>>] Creating markdown files for Buhtrap, Ratopak Spider..
#   [>>] Creating markdown files for Cadelle..
#   [>>] Creating markdown files for Cadet Blizzard..
#   [>>] Creating markdown files for Callisto Group..
#   [>>] Creating markdown files for Calypso..
#   [>>] Creating markdown files for Carbanak, Anunak..
#   [>>] Creating markdown files for Carderbee..
#   [>>] Creating markdown files for CardinalLizard..
#   [>>] Creating markdown files for Careto, The Mask..
#   [>>] Creating markdown files for Chafer, APT 39..
#   [>>] Creating markdown files for ChamelGang..
#   [>>] Creating markdown files for Chimera..
#   [>>] Creating markdown files for CIA..
#   [>>] Creating markdown files for Longhorn, The Lamberts..
#   [>>] Creating markdown files for [Unnamed group USA]..
#   [>>] Creating markdown files for Circus Spider..
#   [>>] Creating markdown files for Clever Kitten..
#   [>>] Creating markdown files for Cobalt Group..
#   [>>] Creating markdown files for Cold River..
#   [>>] Creating markdown files for Comment Crew, APT 1..
#   [>>] Creating markdown files for Confucius..
#   [>>] Creating markdown files for CopyKittens, Slayer Kitten..
#   [>>] Creating markdown files for Corkow, Metel..
#   [>>] Creating markdown files for CostaRicto..
#   [>>] Creating markdown files for Covellite..
#   [>>] Creating markdown files for Curious Gorge..
#   [>>] Creating markdown files for Cutting Kitten, TG-2889..
#   [>>] Creating markdown files for CyberAv3ngers..
#   [>>] Creating markdown files for Cyber Berkut..
#   [>>] Creating markdown files for Cyber Caliphate Army (CCA), United Cyber Caliphate (UCC)..
#   [>>] Creating markdown files for Dalbit..
#   [>>] Creating markdown files for Dark Caracal..
#   [>>] Creating markdown files for DarkCasino..
#   [>>] Creating markdown files for DarkHotel..
#   [>>] Creating markdown files for DarkHydrus, LazyMeerkat..
#   [>>] Creating markdown files for Dark Pink..
#   [>>] Creating markdown files for DarkUniverse..
#   [>>] Creating markdown files for Deceptikons, DeathStalker..
#   [>>] Creating markdown files for Desert Falcons..
#   [>>] Creating markdown files for DNSpionage..
#   [>>] Creating markdown files for Domestic Kitten..
#   [>>] Creating markdown files for Donot Team..
#   [>>] Creating markdown files for Doppel Spider..
#   [>>] Creating markdown files for DragonOK..
#   [>>] Creating markdown files for DragonSpark..
#   [>>] Creating markdown files for DustSquad, Golden Falcon..
#   [>>] Creating markdown files for Dust Storm..
#   [>>] Creating markdown files for Earth Berberoka..
#   [>>] Creating markdown files for Earth Lusca..
#   [>>] Creating markdown files for Earth Wendigo..
#   [>>] Creating markdown files for Elephant Beetle..
#   [>>] Creating markdown files for El Machete..
#   [>>] Creating markdown files for Emissary Panda, APT 27, LuckyMouse, Bronze Union..
#   [>>] Creating markdown files for EmpireMonkey, CobaltGoblin..
#   [>>] Creating markdown files for Energetic Bear, Dragonfly..
#   [>>] Creating markdown files for Equation Group..
#   [>>] Creating markdown files for Evilnum..
#   [>>] Creating markdown files for FamousSparrow..
#   [>>] Creating markdown files for Ferocious Kitten..
#   [>>] Creating markdown files for FIN4, Wolf Spider..
#   [>>] Creating markdown files for FIN5..
#   [>>] Creating markdown files for FIN6, Skeleton Spider..
#   [>>] Creating markdown files for FIN7..
#   [>>] Creating markdown files for FIN8..
#   [>>] Creating markdown files for FIN10..
#   [>>] Creating markdown files for FIN11..
#   [>>] Creating markdown files for FIN12..
#   [>>] Creating markdown files for FIN13..
#   [>>] Creating markdown files for Fishing Elephant..
#   [>>] Creating markdown files for Flax Typhoon..
#   [>>] Creating markdown files for Flying Kitten, Ajax Security Team..
#   [>>] Creating markdown files for FunnyDream..
#   [>>] Creating markdown files for Gallium..
#   [>>] Creating markdown files for Gallmaker..
#   [>>] Creating markdown files for Gamaredon Group..
#   [>>] Creating markdown files for Gangnam Industrial Style..
#   [>>] Creating markdown files for GCHQ..
#   [>>] Creating markdown files for GCMAN..
#   [>>] Creating markdown files for Gelsemium..
#   [>>] Creating markdown files for GhostEmperor..
#   [>>] Creating markdown files for GhostNet, Snooping Dragon..
#   [>>] Creating markdown files for Goblin Panda, Cycldek, Conimes..
#   [>>] Creating markdown files for GoldenJackal..
#   [>>] Creating markdown files for Gorgon Group..
#   [>>] Creating markdown files for Grayling..
#   [>>] Creating markdown files for Group5..
#   [>>] Creating markdown files for Hades..
#   [>>] Creating markdown files for Hafnium..
#   [>>] Creating markdown files for Harvester..
#   [>>] Creating markdown files for Hexane..
#   [>>] Creating markdown files for Hidden Lynx, Aurora Panda..
#   [>>] Creating markdown files for HomeLand Justice..
#   [>>] Creating markdown files for Honeybee..
#   [>>] Creating markdown files for Hurricane Panda..
#   [>>] Creating markdown files for Hydrochasma..
#   [>>] Creating markdown files for IAmTheKing..
#   [>>] Creating markdown files for Icefog, Dagger Panda..
#   [>>] Creating markdown files for Inception Framework, Cloud Atlas..
#   [>>] Creating markdown files for IndigoZebra..
#   [>>] Creating markdown files for Indra..
#   [>>] Creating markdown files for Indrik Spider..
#   [>>] Creating markdown files for Infy, Prince of Persia..
#   [>>] Creating markdown files for InvisiMole..
#   [>>] Creating markdown files for Iridium..
#   [>>] Creating markdown files for IronHusky..
#   [>>] Creating markdown files for ITG18..
#   [>>] Creating markdown files for Karkadann..
#   [>>] Creating markdown files for Ke3chang, Vixen Panda, APT 15, GREF, Playful Dragon..
#   [>>] Creating markdown files for Kimsuky, Velvet Chollima..
#   [>>] Creating markdown files for Lancefly..
#   [>>] Creating markdown files for Lazarus Group, Hidden Cobra, Labyrinth Chollima..
#   [>>] Creating markdown files for Andariel, Silent Chollima..
#   [>>] Creating markdown files for BeagleBoyz..
#   [>>] Creating markdown files for Bluenoroff, APT 38, Stardust Chollima..
#   [>>] Creating markdown files for LazyScripter..
#   [>>] Creating markdown files for Lead..
#   [>>] Creating markdown files for Leafminer, Raspite..
#   [>>] Creating markdown files for leetMX..
#   [>>] Creating markdown files for Leviathan, APT 40, TEMP.Periscope..
#   [>>] Creating markdown files for Libyan Scorpions..
#   [>>] Creating markdown files for LightBasin..
#   [>>] Creating markdown files for LockBit Gang..
#   [>>] Creating markdown files for LookBack, TA410..
#   [>>] Creating markdown files for Lotus Blossom, Spring Dragon, Thrip..
#   [>>] Creating markdown files for Lucky Cat..
#   [>>] Creating markdown files for LuminousMoth..
#   [>>] Creating markdown files for Lurk..
#   [>>] Creating markdown files for Mabna Institute, Cobalt Dickens, Silent Librarian..
#   [>>] Creating markdown files for Madi..
#   [>>] Creating markdown files for Magic Hound, APT 35, Cobalt Illusion, Charming Kitten..
#   [>>] Creating markdown files for DEV-0270, Nemesis Kitten..
#   [>>] Creating markdown files for Magic Kitten..
#   [>>] Creating markdown files for MalKamak..
#   [>>] Creating markdown files for Mallard Spider..
#   [>>] Creating markdown files for Mikroceen..
#   [>>] Creating markdown files for Moafee..
#   [>>] Creating markdown files for Molerats, Extreme Jackal, Gaza Cybergang..
#   [>>] Creating markdown files for MoneyTaker..
#   [>>] Creating markdown files for MoustachedBouncer..
#   [>>] Creating markdown files for MuddyWater, Seedworm, TEMP.Zagros, Static Kitten..
#   [>>] Creating markdown files for Mustang Panda, Bronze President..
#   [>>] Creating markdown files for Naikon, Lotus Panda..
#   [>>] Creating markdown files for Nazar..
#   [>>] Creating markdown files for NB65..
#   [>>] Creating markdown files for Neodymium..
#   [>>] Creating markdown files for NetTraveler, APT 21, Hammer Panda..
#   [>>] Creating markdown files for Night Dragon..
#   [>>] Creating markdown files for Nightshade Panda, APT 9, Group 27..
#   [>>] Creating markdown files for NineBlog..
#   [>>] Creating markdown files for Nitro, Covert Grove..
#   [>>] Creating markdown files for OilAlpha..
#   [>>] Creating markdown files for OilRig, APT 34, Helix Kitten, Chrysene..
#   [>>] Creating markdown files for Greenbug, Volatile Kitten..
#   [>>] Creating markdown files for OldGremlin..
#   [>>] Creating markdown files for OnionDog..
#   [>>] Creating markdown files for OPERA1ER..
#   [>>] Creating markdown files for Operation Armor Piercer..
#   [>>] Creating markdown files for Operation Bandidos..
#   [>>] Creating markdown files for Operation Black Atlas..
#   [>>] Creating markdown files for Operation BugDrop..
#   [>>] Creating markdown files for Operation Comando..
#   [>>] Creating markdown files for Operation Domino, Operation Kremlin..
#   [>>] Creating markdown files for Operation Dragon Castling..
#   [>>] Creating markdown files for Operation Earth Kitsune..
#   [>>] Creating markdown files for Operation Electric Powder..
#   [>>] Creating markdown files for Operation EmailThief, TEMP_Heretic..
#   [>>] Creating markdown files for Operation Epic Manchego..
#   [>>] Creating markdown files for Operation Ghostwriter..
#   [>>] Creating markdown files for Operation Ghoul..
#   [>>] Creating markdown files for Operation Groundbait..
#   [>>] Creating markdown files for Operation HangOver, Monsoon, Viceroy Tiger..
#   [>>] Creating markdown files for Operation Harvest..
#   [>>] Creating markdown files for Operation Jacana..
#   [>>] Creating markdown files for Operation Layover..
#   [>>] Creating markdown files for Operation LiberalFace, MirrorFace..
#   [>>] Creating markdown files for Operation Manul..
#   [>>] Creating markdown files for Operation Olympic Games..
#   [>>] Creating markdown files for Operation Parliament..
#   [>>] Creating markdown files for Operation Poisoned News, TwoSail Junk..
#   [>>] Creating markdown files for Operation Poison Needles..
#   [>>] Creating markdown files for Operation Potao Express..
#   [>>] Creating markdown files for Operation PseudoManuscrypt..
#   [>>] Creating markdown files for Operation Red Signature..
#   [>>] Creating markdown files for Operation RestyLink..
#   [>>] Creating markdown files for Operation RusticWeb..
#   [>>] Creating markdown files for Operation Rusty Flag..
#   [>>] Creating markdown files for Operation Shady RAT..
#   [>>] Creating markdown files for Operation SignSight..
#   [>>] Creating markdown files for Operation Silent Skimmer..
#   [>>] Creating markdown files for Operation Spalax..
#   [>>] Creating markdown files for Operation Titan Rain..
#   [>>] Creating markdown files for Operation Triangulation..
#   [>>] Creating markdown files for Operation TunnelSnake..
#   [>>] Creating markdown files for Operation ViceLeaker..
#   [>>] Creating markdown files for Operation WizardOpium..
#   [>>] Creating markdown files for Orangeworm..
#   [>>] Creating markdown files for Packrat..
#   [>>] Creating markdown files for Parisite, Fox Kitten, Pioneer Kitten..
#   [>>] Creating markdown files for PassCV..
#   [>>] Creating markdown files for Patchwork, Dropping Elephant..
#   [>>] Creating markdown files for Pinchy Spider, Gold Southfield..
#   [>>] Creating markdown files for PittyTiger, Pitty Panda..
#   [>>] Creating markdown files for PKPLUG..
#   [>>] Creating markdown files for Platinum..
#   [>>] Creating markdown files for Poison Carp, Evil Eye..
#   [>>] Creating markdown files for Polonium..
#   [>>] Creating markdown files for Poseidon Group..
#   [>>] Creating markdown files for PowerPool..
#   [>>] Creating markdown files for Promethium, StrongPity..
#   [>>] Creating markdown files for Pusikurac..
#   [>>] Creating markdown files for Putter Panda, APT 2..
#   [>>] Creating markdown files for Rampant Kitten..
#   [>>] Creating markdown files for Rancor..
#   [>>] Creating markdown files for RATicate..
#   [>>] Creating markdown files for Reaper, APT 37, Ricochet Chollima, ScarCruft..
#   [>>] Creating markdown files for RedAlpha..
#   [>>] Creating markdown files for RedCurl..
#   [>>] Creating markdown files for RedDelta..
#   [>>] Creating markdown files for RedEcho..
#   [>>] Creating markdown files for RedFoxtrot..
#   [>>] Creating markdown files for RedGolf..
#   [>>] Creating markdown files for RedHotel, TAG-22..
#   [>>] Creating markdown files for RevengeHotels..
#   [>>] Creating markdown files for Riddle Spider..
#   [>>] Creating markdown files for Roaming Tiger..
#   [>>] Creating markdown files for Rocket Kitten, Newscaster, NewsBeef..
#   [>>] Creating markdown files for RTM..
#   [>>] Creating markdown files for Safe..
#   [>>] Creating markdown files for SaintBear, Lorec53..
#   [>>] Creating markdown files for Samurai Panda..
#   [>>] Creating markdown files for SandCat..
#   [>>] Creating markdown files for Sandman..
#   [>>] Creating markdown files for Sandworm Team, Iron Viking, Voodoo Bear..
#   [>>] Creating markdown files for Scarab..
#   [>>] Creating markdown files for Scarlet Mimic..
#   [>>] Creating markdown files for Sea Turtle..
#   [>>] Creating markdown files for Shadow Academy..
#   [>>] Creating markdown files for Shadow Network..
#   [>>] Creating markdown files for ShaggyPanther..
#   [>>] Creating markdown files for SharpPanda..
#   [>>] Creating markdown files for ShroudedSnooper..
#   [>>] Creating markdown files for SideCopy..
#   [>>] Creating markdown files for SideWinder, Rattlesnake..
#   [>>] Creating markdown files for Siesta..
#   [>>] Creating markdown files for Silence, Contract Crew..
#   [>>] Creating markdown files for Sima..
#   [>>] Creating markdown files for Slingshot..
#   [>>] Creating markdown files for Snake Wine..
#   [>>] Creating markdown files for Snowglobe, Animal Farm..
#   [>>] Creating markdown files for Sofacy, APT 28, Fancy Bear, Sednit..
#   [>>] Creating markdown files for Sowbug..
#   [>>] Creating markdown files for Space Pirates..
#   [>>] Creating markdown files for Sphinx..
#   [>>] Creating markdown files for Sprite Spider, Gold Dupont..
#   [>>] Creating markdown files for Stealth Falcon, FruityArmor..
#   [>>] Creating markdown files for Stone Panda, APT 10, menuPass..
#   [>>] Creating markdown files for Storm-0558..
#   [>>] Creating markdown files for Strider, ProjectSauron..
#   [>>] Creating markdown files for Suckfly..
#   [>>] Creating markdown files for SunCrypt Gang..
#   [>>] Creating markdown files for Sweed..
#   [>>] Creating markdown files for Syrian Electronic Army (SEA), Deadeye Jackal..
#   [>>] Creating markdown files for Goldmouse, APT-C-27..
#   [>>] Creating markdown files for Pat Bear, APT-C-37..
#   [>>] Creating markdown files for TA2101, Maze Team..
#   [>>] Creating markdown files for TA2541..
#   [>>] Creating markdown files for TA2552..
#   [>>] Creating markdown files for TA2722..
#   [>>] Creating markdown files for TA413..
#   [>>] Creating markdown files for TA428..
#   [>>] Creating markdown files for TA459..
#   [>>] Creating markdown files for TA505, Graceful Spider, Gold Evergreen..
#   [>>] Creating markdown files for TA530..
#   [>>] Creating markdown files for TA555..
#   [>>] Creating markdown files for TA558..
#   [>>] Creating markdown files for TAG-28..
#   [>>] Creating markdown files for TAG-38..
#   [>>] Creating markdown files for Taidoor..
#   [>>] Creating markdown files for TaskMasters..
#   [>>] Creating markdown files for TeamSpy Crew..
#   [>>] Creating markdown files for TeleBots..
#   [>>] Creating markdown files for Temper Panda, admin@338..
#   [>>] Creating markdown files for Tempting Cedar Spyware..
#   [>>] Creating markdown files for TEMP.Veles..
#   [>>] Creating markdown files for Terbium..
#   [>>] Creating markdown files for Tiny Spider..
#   [>>] Creating markdown files for ToddyCat..
#   [>>] Creating markdown files for Tomiris..
#   [>>] Creating markdown files for Tonto Team, HartBeat, Karma Panda..
#   [>>] Creating markdown files for Tortilla..
#   [>>] Creating markdown files for Tortoiseshell, Imperial Kitten..
#   [>>] Creating markdown files for Tracer Kitten..
#   [>>] Creating markdown files for Transparent Tribe, APT 36..
#   [>>] Creating markdown files for Traveling Spider..
#   [>>] Creating markdown files for Tropical Scorpius, RomCom..
#   [>>] Creating markdown files for Tropic Trooper, Pirate Panda, APT 23, KeyBoy..
#   [>>] Creating markdown files for Turbine Panda, APT 26, Shell Crew, WebMasters, KungFu Kittens..
#   [>>] Creating markdown files for Turla, Waterbug, Venomous Bear..
#   [>>] Creating markdown files for Twisted Panda..
#   [>>] Creating markdown files for UltraRank..
#   [>>] Creating markdown files for UNC215..
#   [>>] Creating markdown files for UNC2447..
#   [>>] Creating markdown files for UNC2891..
#   [>>] Creating markdown files for UNC3524..
#   [>>] Creating markdown files for UNC4191..
#   [>>] Creating markdown files for UNC5221, UTA0178..
#   [>>] Creating markdown files for Urpage..
#   [>>] Creating markdown files for Vendetta, TA2719..
#   [>>] Creating markdown files for Venom Spider, Golden Chickens..
#   [>>] Creating markdown files for Vicious Panda..
#   [>>] Creating markdown files for Viking Spider..
#   [>>] Creating markdown files for Void Balaur..
#   [>>] Creating markdown files for Volatile Cedar..
#   [>>] Creating markdown files for Volt Typhoon..
#   [>>] Creating markdown files for Wassonite..
#   [>>] Creating markdown files for The White Company..
#   [>>] Creating markdown files for Whitefly, Mofang..
#   [>>] Creating markdown files for Wicked Spider, APT 22..
#   [>>] Creating markdown files for WildCard..
#   [>>] Creating markdown files for Wild Neutron, Butterfly, Sphinx Moth..
#   [>>] Creating markdown files for WildPressure..
#   [>>] Creating markdown files for WindShift..
#   [>>] Creating markdown files for Winnti Group, Blackfly, Wicked Panda..
#   [>>] Creating markdown files for Winter Vivern..
#   [>>] Creating markdown files for WIP26..
#   [>>] Creating markdown files for WIRTE Group..
#   [>>] Creating markdown files for Wizard Spider, Gold Blackburn..
#   [>>] Creating markdown files for Worok..
#   [>>] Creating markdown files for XDSpy..
#   [>>] Creating markdown files for xHunt..
#   [>>] Creating markdown files for YoroTrooper..
#   [>>] Creating markdown files for ZooPark..
#   [>>] Creating markdown files for [Unnamed group Iran]..
#   [>>] Creating markdown files for 8220 Gang..
#   [>>] Creating markdown files for Achilles..
#   [>>] Creating markdown files for ALTDOS..
#   [>>] Creating markdown files for Andromeda Spider..
#   [>>] Creating markdown files for Avalanche..
#   [>>] Creating markdown files for Bamboo Spider, TA544..
#   [>>] Creating markdown files for Bismuth..
#   [>>] Creating markdown files for Boson Spider..
#   [>>] Creating markdown files for Circles..
#   [>>] Creating markdown files for Cron..
#   [>>] Creating markdown files for Cyber fighters of Izz Ad-Din Al Qassam, Fraternal Jackal..
#   [>>] Creating markdown files for Dark Basin..
#   [>>] Creating markdown files for Desorden..
#   [>>] Creating markdown files for Dungeon Spider..
#   [>>] Creating markdown files for Fxmsp..
#   [>>] Creating markdown files for GambleForce..
#   [>>] Creating markdown files for Gnosticplayers..
#   [>>] Creating markdown files for Guru Spider..
#   [>>] Creating markdown files for Hacking Team..
#   [>>] Creating markdown files for Handala Hack Team..
#   [>>] Creating markdown files for Infraud Organization..
#   [>>] Creating markdown files for Karakurt..
#   [>>] Creating markdown files for Lapsus$..
#   [>>] Creating markdown files for Lunar Spider..
#   [>>] Creating markdown files for Monty Spider..
#   [>>] Creating markdown files for Moses Staff..
#   [>>] Creating markdown files for Mummy Spider, TA542..
#   [>>] Creating markdown files for Narwhal Spider..
#   [>>] Creating markdown files for NetSec, USDoD..
#   [>>] Creating markdown files for OurMine..
#   [>>] Creating markdown files for Operation Windigo..
#   [>>] Creating markdown files for Pacha Group..
#   [>>] Creating markdown files for Parinacota..
#   [>>] Creating markdown files for Planetary Reef..
#   [>>] Creating markdown files for Retefe Gang, Operation Emmental..
#   [>>] Creating markdown files for Roaming Mantis..
#   [>>] Creating markdown files for Rocke, Iron Group..
#   [>>] Creating markdown files for Salty Spider..
#   [>>] Creating markdown files for Scully Spider, TA547..
#   [>>] Creating markdown files for Shadow Brokers..
#   [>>] Creating markdown files for ShinyHunters..
#   [>>] Creating markdown files for Shark Spider..
#   [>>] Creating markdown files for Smoky Spider..
#   [>>] Creating markdown files for TA511..
#   [>>] Creating markdown files for TA516..
#   [>>] Creating markdown files for TA551, Shathak..
#   [>>] Creating markdown files for TA554..
#   [>>] Creating markdown files for UNC1878..
#   [>>] Creating markdown files for [Vault 7/8]..
#   [>>] Creating markdown files for Yanbian Gang..
#   [>>] Creating markdown files for Yingmob..
#   [>>] Creating markdown files for Zombie Spider..

# %% [markdown]
# # Load documents for indexing

# %%
report_files = glob.glob(os.path.join(reports_directory, "*/*.md"), recursive=True)

md_docs = []
print("[+] Loading group markdown files..")
for report in report_files:
    print(f' [*] Loading {os.path.basename(report)}')
    loader = UnstructuredMarkdownLoader(report)
    md_docs.extend(loader.load())

print(f'[+] Number of .md documents processed: {len(md_docs)}')
# Out:
# [+] Loading Group markdown files..
#  [*] Loading 8220_Gang.md
#  [*] Loading 8220_Gang_Cloud_Botnet_Targets_Misconfigured_Cloud_Workloads_-_SentinelOne.md
#  [*] Loading 8220_Gang_Evolves_With_New_Strategies.md
#  [*] Loading 8220_Gangs_Recent_use_of_Custom_Miner_and_Botnet.md
#  [*] Loading From_the_Front_Lines_|_8220_Gang_Massively_Expands_Cloud_Botnet_to_30,000_Infected_Hosts_-_SentinelOne.md
#  [*] Loading Imperva_Detects_Undocumented_8220_Gang_Activities_|_Imperva.md
#  [*] Loading Radware_Page.md
#  [*] Loading Achilles.md
#  [*] Loading Another_Hacker_Selling_Access_to_Charity,_Antivirus_Firm_Networks.md
#  [*] Loading Iranian_hackers_suspected_in_cyber_breach_and_extortion_attempt_on_Navy_shipbuilder_Austal_-_ABC_News.md
#  [*] Loading AeroBlade.md
#  [*] Loading AeroBlade_on_the_Hunt_Targeting_the_U.S._Aerospace_Industry.md
#  [*] Loading APT_or_not_APT?_What's_Behind_the_Aggah_Campaign_-_Yoroi.md
#  [*] Loading Aggah.md
#  [*] Loading Aggah:_How_to_run_a_botnet_without_renting_a_Server_(for_more_than_a_year)_-_Yoroi.md
#  [*] Loading Aggah_Campaign:_Bit.ly,_BlogSpot,_and_Pastebin_Used_for_C2_in_Large_Scale_Campaign.md
#  [*] Loading Aggah_Using_Compromised_Websites_to_Target_Businesses_Across_Asia,_Including_Taiwan_Manufacturing_Industry_|_Anomali.md
#  [*] Loading Aghast_at_Aggah:_Teasing_Security_Controls_with_Advanced_Evasion_Techniques.md
#  [*] Loading Cyber-Criminal_espionage_Operation_insists_on_Italian_Manufacturing_-_Yoroi.md
#  [*] Loading Microsoft_Defender_Threat_Intelligence_|_Microsoft_Security.md
#  [*] Loading The_Enigmatic_“Roma225”_Campaign_-_Yoroi.md
#  [*] Loading The_Evolution_of_Aggah:_From_Roma225_to_the_RG_Campaign_-_Yoroi.md
#  [*] Loading Agrius.md
#  [*] Loading Fantasy_–_a_new_Agrius_wiper_deployed_through_a_supply-chain_attack.md
#  [*] Loading From_Wiper_To_Ransomware_The_Evolution_Of_Agrius.md
#  [*] Loading ALLANITE_Threat_Group_|_Dragos.md
#  [*] Loading Allanite.md
#  [*] Loading ALPHV,_BlackCat_Gang.md
#  [*] Loading ALPHV_Ransomware_Affiliate_Targets_Vulnerable_Backup_Installations_to_Gain_Initial_Access_|_Mandiant.md
#  [*] Loading ALPHV_gang_claims_ransomware_attack_on_Constellation_Software.md
#  [*] Loading ALPHV_ransomware_adds_data_leak_API_in_new_extortion_strategy.md
#  [*] Loading ALPHV_ransomware_gang_claims_attack_on_Florida_circuit_court.md
#  [*] Loading AlphV_group_takes_credit_for_ransomware_attack_on_Georgia_county.md
#  [*] Loading Alphv_gang_stole_5TB_of_data_from_Morrison_Community_Hospital.md
#  [*] Loading Alphv group_claims_the_hack_of_Clarion,_a_global_manufacturer_of_audio_and_video_equipment_for_cars.md
#  [*] Loading Amazon-owned_Ring_denies_‘ransomware_event’_following_darknet_listing.md
#  [*] Loading An_ALPHV_(BlackCat)_representative_discusses_the_group’s_plans_for_a_ransomware_‘meta-universe’.md
#  [*] Loading Attention_Required!_|_Cloudflare.md
#  [*] Loading Australian_Law_Firm_Hack_Impacted_65_Government_Agencies.md
#  [*] Loading Bandai_Namco_confirms_hack_after_ALPHV_ransomware_data_leak_threat.md
#  [*] Loading BlackCat,_Clop_claim_ransomware_attack_on_cosmetics_maker_Estee_Lauder.md
#  [*] Loading BlackCat_(ALPHV)_Ransomware_Levels_Up_for_Stealth,_Speed_and_Exfiltration.md
#  [*] Loading BlackCat_(ALPHV)_claims_Swissport_ransomware_attack,_leaks_data.md
#  [*] Loading BlackCat_ALPHV_ransomware_asks_$5_million_to_unlock_Austrian_state.md
#  [*] Loading BlackCat_Adds_Indian_Missile_Fuel_Maker_to_Its_Victims_List.md
#  [*] Loading BlackCat_Attacks_University_of_Pisa,_Demands_$4.5M_Ransom.md
#  [*] Loading BlackCat_Climbs_the_Summit_With_a_New_Tactic.md
#  [*] Loading BlackCat_Ransomware_gang_stole_secret_military_data_from_industrial_explosives_manufacturer.md
#  [*] Loading BlackCat_gang_threatens_to_leak_plastic_surgery_photos_•_The_Register.md
#  [*] Loading BlackCat_ransomware_claims_attack_on_European_gas_pipeline.md
#  [*] Loading BlackCat_ransomware_claims_attack_on_Italian_energy_agency.md
#  [*] Loading BlackCat_ransomware_claims_breach_of_healthcare_giant_Henry_Schein.md
#  [*] Loading BlackCat_ransomware_fails_to_extort_Australian_commercial_law_giant.md
#  [*] Loading BlackCat_ransomware_hits_Azure_Storage_with_Sphynx_encryptor.md
#  [*] Loading BlackCat_ransomware_implicated_in_attack_on_German_oil_companies_|_ZDNET.md
#  [*] Loading Colombian_energy_supplier_EPM_hit_by_BlackCat_ransomware_attack.md
#  [*] Loading Everything_You_Need_To_Know_About_BlackCat_(AlphaV).md
#  [*] Loading FBI:_ALPHV_ransomware_raked_in_$300_million_from_over_1,000_victims.md
#  [*] Loading Fashion_giant_Moncler_confirms_data_breach_after_ransomware_attack.md
#  [*] Loading Global_IT_services_provider_Inetum_hit_by_ransomware_attack.md
#  [*] Loading HTC_Global_Services_confirms_cyberattack_after_data_leaked_online.md
#  [*] Loading Indian_pharmaceutical_giant_warns_of_revenue_loss,_litigation_after_ransomware_attack.md
#  [*] Loading Japanese_watchmaker_Seiko_breached_by_BlackCat_ransomware_gang.md
#  [*] Loading Large_Michigan_healthcare_provider_confirms_ransomware_attack.md
#  [*] Loading Legal_services_platform_used_by_SEC,_Pentagon_investigating_ransomware_attack_claims.md
#  [*] Loading Lockbit,_Hive,_and_BlackCat_attack_automotive_supplier_in_triple_ransomware_attack_–_Sophos_News.md
#  [*] Loading Louisiana_authorities_investigating_ransomware_attack_on_city_of_Alexandria.md
#  [*] Loading Major_airline_technology_provider_Accelya_attacked_by_ransomware_group.md
#  [*] Loading Malvertising_Used_as_Entry_Vector_for_BlackCat_Actors_Also_Leverage_SpyBoy_Terminator_.md
#  [*] Loading McLaren_Health_Care_says_data_breach_impacted_2.2_million_people.md
#  [*] Loading Microsoft:_BlackCat's_Sphynx_ransomware_embeds_Impacket,_RemCom.md
#  [*] Loading Motel_One_discloses_data_breach_following_ransomware_attack.md
#  [*] Loading Norton_Healthcare_discloses_data_breach_after_May_ransomware_attack.md
#  [*] Loading Notorious_ransomware_gang_takes_credit_for_cyberattack_on_Fidelity_National_Financial.md
#  [*] Loading Pennsylvania_Health_System_CEO_Confirms_BlackCat_Attack.md
#  [*] Loading Product_leasing_giant_warns_that_sensitive_information_was_stolen_during_cyberattack.md
#  [*] Loading Ransomware_gang_cloned_victim’s_website_to_leak_stolen_data.md
#  [*] Loading Ransomware_gang_creates_site_for_employees_to_search_for_their_stolen_data.md
#  [*] Loading Ransomware_gang_posts_breast_cancer_patients’_clinical_photographs.md
#  [*] Loading Reddit_hackers_threaten_to_leak_data_stolen_in_February_breach.md
#  [*] Loading Resecurity_|_BlackCat_(aka_ALPHV)_Ransomware_is_Increasing_Stakes_up_to_$2,5M_in_Demands.md
#  [*] Loading String_of_cyberattacks_on_European_oil_and_chemical_sectors_likely_not_coordinated,_officials_say.md
#  [*] Loading Threat_Assessment:_BlackCat_Ransomware.md
#  [*] Loading Toy_maker_Jakks_Pacific_reports_cyberattack_after_multiple_ransomware_groups_leak_data.md
#  [*] Loading Update:_What's_BlackCat_Ransomware_Been_Up_to_Recently?.md
#  [*] Loading Who_Wrote_the_ALPHV_BlackCat_Ransomware_Strain?_–_Krebs_on_Security.md
#  [*] Loading eSentire_|_The_ALPHV_BlackCat_Ransomware_Gang_is_Using_Google_Ads_to….md
#  [*] Loading summaries.md
#  [*] Loading ALTDOS.md
#  [*] Loading Audio_House_customer_data_possibly_stolen_by_hackers_|_The_Straits_Times.md
#  [*] Loading Anchor_Panda,_APT_14.md
#  [*] Loading Anchor_Panda_|_Threat_Actor_Profile_|_CrowdStrike.md
#  [*] Loading Analysis_of_Andariel's_New_Attack_Activities_-_ASEC_BLOG.md
#  [*] Loading Andariel,_Silent_Chollima.md
#  [*] Loading Andariel_deploys_DTrack_and_Maui_ransomware_|_Securelist.md
#  [*] Loading Andariel_evolves_to_target_South_Korea_with_ransomware_|_Securelist.md
#  [*] Loading Circumstances_of_an_Attack_Exploiting_an_Asset_Management_Program_(Andariel_Group)_-_ASEC_BLOG.md
#  [*] Loading Circumstances_of_the_Andariel_Group_Exploiting_an_Apache_ActiveMQ_Vulnerability_(CVE-2023-46604)_-_ASEC_BLOG.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Kaspersky_crimeware_report:_Andariel’s_mistakes_and_EasyRat_malware_|_Securelist.md
#  [*] Loading Multiple_North_Korean_threat_actors_exploiting_the_TeamCity_CVE-2023-42793_vulnerability_|_Microsoft_Security_Blog.md
#  [*] Loading New_Andariel_Reconnaissance_Tactics_Uncovered.md
#  [*] Loading North_Korean_hackers_stole_anti-aircraft_system_data_from_South_Korean_firm.md
#  [*] Loading Andromeda_Spider.md
#  [*] Loading Andromeda_under_the_microscope.md
#  [*] Loading Virus_Bulletin_::_A_review_of_the_evolution_of_Andromeda_over_the_years_before_we_say_goodbye.md
#  [*] Loading Antlion.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Aoqin_Dragon.md
#  [*] Loading Aoqin_Dragon_|_Newly-Discovered_Chinese-linked_APT_Has_Been_Quietly_Spying_On_Organizations_For_10_Years_-_SentinelOne.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading APT3_is_Boyusec,_a_Chinese_Intelligence_Contractor_–_Intrusion_Truth.md
#  [*] Loading APT_3,_Gothic_Panda,_Buckeye.md
#  [*] Loading Operation_Clandestine_Wolf_–_Adobe_Flash_Zero-Day_in_APT3_Phishing_Campaign_|_Mandiant.md
#  [*] Loading Operation_Double_Tap_|_Mandiant.md
#  [*] Loading Recorded_Future_Research_Concludes_Chinese_Ministry_of_State_Security_Behind_APT3_|_Recorded_Future.md
#  [*] Loading APT_4,_Maverick_Panda,_Wisp_Team.md
#  [*] Loading Are_the_Sykipot’s_authors_obsessed_with_next_generation_US_drones?.md
#  [*] Loading Asia_in_the_crosshairs_of_APT_attackers:_FireEye_CTO_|_Digital_News_Asia.md
#  [*] Loading New_Sykipot_developments.md
#  [*] Loading Research,_News,_and_Perspectives.md
#  [*] Loading Sykipot_is_back.md
#  [*] Loading Sykipot_variant_hijacks_DOD_and_Windows_smart_cards.md
#  [*] Loading APT_5,_Keyhole_Panda.md
#  [*] Loading A_Chinese_APT_is_now_going_after_Pulse_Secure_and_Fortinet_VPN_servers_|_ZDNET.md
#  [*] Loading APT_6.md
#  [*] Loading FBI_Quietly_Admits_to_Multi-Year_APT_Attack,_Sensitive_Data_Stolen_|_Threatpost.md
#  [*] Loading APT_12,_Numbered_Panda.md
#  [*] Loading CNACOM_Open_Source_Exploitation_via_Strategic_Web_Compromise.md
#  [*] Loading Chinese_Hackers_Infiltrate_New_York_Times_Computers_-_The_New_York_Times.md
#  [*] Loading Darwin’s_Favorite_APT_Group_|_Mandiant.md
#  [*] Loading Numbered_Panda_-_Wikipedia.md
#  [*] Loading Read_Featured_Article_"Whois_Numbered_Panda"_by_Adam_Meyers.md
#  [*] Loading Research,_News,_and_Perspectives.md
#  [*] Loading APT_16,_SVCMONDR.md
#  [*] Loading CVE-2015-2545:_overview_of_current_threats_|_Securelist.md
#  [*] Loading
# Official_Google_Blog:_A_new_approach_to_China
# .md
#  [*] Loading APT17_is_run_by_the_Jinan_bureau_of_the_Chinese_Ministry_of_State_Security_–_Intrusion_Truth.md
#  [*] Loading APT_17,_Deputy_Dog,_Elderwood,_Sneaky_Panda.md
#  [*] Loading Amnesty_International_UK_site_flung_Gh0st_RAT_at_surfers_after_hack_•_The_Register.md
#  [*] Loading Bit9_breach_–_Krebs_on_Security.md
#  [*] Loading Nasty_IE_0day_exploit_hosted_on_Amnesty_International_site_•_The_Register.md
#  [*] Loading Operation_Aurora:_Supply_Chain_Attack_Through_CCleaner_-_Intezer.md
#  [*] Loading Operation_RAT_Cook:_Chinese_APT_actors_use_fake_Game_of_Thrones_leaks_as_lures_|_Proofpoint_US.md
#  [*] Loading Ties_Uncovered_Between_CCleaner_&_Chinese_Hackers_Part_2_-_Intezer.md
#  [*] Loading APT_18,_Dynamite_Panda,_Wekby.md
#  [*] Loading Chinese_cyberespionage_bootcamps_training_recruits_in_the_art_of_supply_chain_attacks_for_over_a_decade.md
#  [*] Loading Demonstrating_Hustle,_Chinese_APT_Groups_Quickly_Use_Zero-Day_Vulnerability_(CVE-2015-5119)_Following_Hacking_Team_Leak_|_Mandiant.md
#  [*] Loading New_Wekby_Attacks_Use_DNS_Requests_As_Command_and_Control_Mechanism.md
#  [*] Loading APT_19,_Deep_Panda,_C0d0so0.md
#  [*] Loading Anthem_Breach_May_Have_Started_in_April_2014_–_Krebs_on_Security.md
#  [*] Loading Carefirst_Blue_Cross_Breach_Hits_1.1M_–_Krebs_on_Security.md
#  [*] Loading Catching_Up_on_the_OPM_Breach_–_Krebs_on_Security.md
#  [*] Loading Chinese_Hacking_Group_Codoso_Team_Uses_Forbes.com_As_Watering_Hole.md
#  [*] Loading Chinese_hackers_'breach_Australian_media_organisations'_ahead_of_G20_-_ABC_News.md
#  [*] Loading Chinese_hackers_targeting_Australian_law_firms,_an_industry_specialist_warns_-_ABC_News.md
#  [*] Loading Chinese_hacking_group_uses_new_'Fire_Chili'_Windows_rootkit.md
#  [*] Loading Cybersecurity_Blog_|_CrowdStrike.md
#  [*] Loading DEEP_PANDA_Uses_Sakula_Malware_to_Target_Organizations.md
#  [*] Loading Deep_in_Thought:_Chinese_Targeting_of_National_Security_Think_Tanks_-_crowdstrike.com.md
#  [*] Loading Feds_warned_Premera_about_security_flaws_before_breach_|_The_Seattle_Times.md
#  [*] Loading KeyPoint_network_breach_could_affect_thousands_of_federal_workers_-_The_Washington_Post.md
#  [*] Loading New_Attacks_Linked_to_C0d0so0_Group.md
#  [*] Loading Privileges_and_Credentials:_Phished_at_the_Request_of_Counsel_|_Mandiant.md
#  [*] Loading Third-Party_Software_Was_Entry_Point_for_Background-Check_System_Hack_-_Nextgov_FCW.md
#  [*] Loading APT_20,_Violin_Panda.md
#  [*] Loading Recent_Watering_Hole_Attacks_Attributed_to_APT_Group_“th3bug”_Using_Poison_Ivy.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading APT29_Continues_Targeting_Microsoft_365_|_You_Can’t_Audit_Me.md
#  [*] Loading APT_29,_Cozy_Bear,_The_Dukes.md
#  [*] Loading Bloomberg_-_Are_you_a_robot?.md
#  [*] Loading Cloaked_Ursa_(APT29)_Hackers_Use_Trusted_Online_Storage_Services.md
#  [*] Loading Cozy_Bear_-_Wikipedia.md
#  [*] Loading Cyber_Security_Works_-_404.md
#  [*] Loading Diplomats_Beware:_Cloaked_Ursa_Phishing_With_a_Twist.md
#  [*] Loading FoggyWeb:_Targeted_NOBELIUM_malware_leads_to_persistent_backdoor_|_Microsoft_Security_Blog.md
#  [*] Loading France_warns_of_Nobelium_cyberspies_attacking_French_orgs.md
#  [*] Loading German_Embassy_Lure:_Likely_Part_of_Campaign_Against_NATO_Aligned_Ministries_of_Foreign_Affairs.md
#  [*] Loading IBM_X-Force_Exchange.md
#  [*] Loading Kremlin-backed_hacking_group_puts_fresh_emphasis_on_stealing_credentials.md
#  [*] Loading MagicWeb:_NOBELIUM’s_post-compromise_trick_to_authenticate_as_anyone_|_Microsoft_Security_Blog.md
#  [*] Loading Microsoft_Defender_Threat_Intelligence_|_Microsoft_Security.md
#  [*] Loading Midnight_Blizzard_conducts_targeted_social_engineering_over_Microsoft_Teams_|_Microsoft_Security_Blog.md
#  [*] Loading Miniduke_is_back:_Nemesis_Gemina_and_the_Botgen_Studio_|_Securelist.md
#  [*] Loading NOBELIUM_Uses_Poland's_Ambassador’s_Visit_to_the_U.S._to_Target_EU_Governments_Assisting_Ukraine.md
#  [*] Loading Nobelium_Returns_to_the_Political_World_Stage_|_FortiGuard_Labs .md
#  [*] Loading Norway:_Russian_hackers_hit_spy_agency,_defense,_Labour_party.md
#  [*] Loading Not_So_Cozy:_An_Uncomfortable_Examination_of_a_Suspected_APT29_Phishing_Campaign_|_Mandiant.md
#  [*] Loading Operation_Ghost:_The_Dukes_aren’t_back_–_they_never_left.md
#  [*] Loading Our_Work_with_the_DNC:_Setting_the_record_straight.md
#  [*] Loading PowerDuke:_Widespread_Post-Election_Spear_Phishing_Campaigns_Targeting_Think_Tanks_and_NGOs_|_Volexity.md
#  [*] Loading Russen_faalden_bij_hackpogingen_ambtenaren_op_Nederlandse_ministeries_.md
#  [*] Loading Russian_Foreign_Intelligence_Service_(SVR)_Exploiting_JetBrains_TeamCity_CVE_Globally_|_CISA.md
#  [*] Loading Russian_cyberspies_targeted_the_Slovak_government_for_months.md
#  [*] Loading Russian_hackers_breached_Dutch_police_systems_in_2017.md
#  [*] Loading SOLARDEFLECTION_C2_Infrastructure_Used_by_NOBELIUM_in_Company_Brand_Misuse.md
#  [*] Loading StellarParticle_Campaign:_Novel_Tactics_and_Techniques_|_CrowdStrike.md
#  [*] Loading Suspected_APT29_Operation_Launches_Election_Fraud_Themed_Phishing_Campaigns_|_Volexity.md
#  [*] Loading Suspected_Russian_Activity_Targeting_Government_and_Business_Entities_Around_the_Globe_|_Mandiant.md
#  [*] Loading The_Dukes_of_Moscow_-_VMware_Security_Blog_-_VMware.md
#  [*] Loading They_See_Me_Roaming:_Following_APT29_by_Taking_a_Deeper_Look_at_Windows_Credential_Roaming_|_Mandiant.md
#  [*] Loading Tracking_APT29_Phishing_Campaigns_|_Atlassian_Trello.md
#  [*] Loading UNC2452_Merged_into_APT29_|_Russia-Based_Espionage_Group.md
#  [*] Loading APT_30,_Override_Panda.md
#  [*] Loading APT31_new_dropper._Target_destinations:_Mongolia,_Russia,_the_U.S.,_and_elsewhere.md
#  [*] Loading APT_31,_Judgment_Panda,_Zirconium.md
#  [*] Loading APTs_Targeting_Journalists_&_Media_Organizations_|_Proofpoint_US.md
#  [*] Loading Chinese_nation_state_hackers_linked_to_Finnish_Parliament_hack.md
#  [*] Loading Definitive_Dossier_of_Devilish_Debug_Details_–_Part_One:_PDB_Paths_and_Malware_|_Mandiant.md
#  [*] Loading France_warns_of_APT31_cyberspies_targeting_French_organizations.md
#  [*] Loading Google:_Chinese_hackers_target_Gmail_users_affiliated_with_US_govt.md
#  [*] Loading Google_warned_users_of_33,000_state-sponsored_attacks_in_2020.md
#  [*] Loading Hackers_use_new_malware_to_breach_air-gapped_devices_in_Eastern_Europe.md
#  [*] Loading Microsoft_Offers_Analysis_of_Zero-Day_Exploited_By_Zirconium_Group_|_Threatpost.md
#  [*] Loading Norway_says_Chinese_group_APT31_is_behind_catastrophic_2018_government_hack.md
#  [*] Loading Uncovering_2017’s_Largest_Malvertising_Operation_|_by_Jerome_Dangu_|_Confiant.md
#  [*] Loading Walking_on_APT31_infrastructure_footprints.md
#  [*] Loading Zirconium_was_one_step_ahead_of_Chrome’s_redirect_blocker_with_0-day_|_by_Jerome_Dangu_|_Confiant.md
#  [*] Loading APT_32,_OceanLotus,_SeaLotus.md
#  [*] Loading BMW_and_Hyundai_hacked_by_Vietnamese_hackers,_report_claims_|_ZDNET.md
#  [*] Loading Bitdefender_Labs.md
#  [*] Loading Chinese_VPN_Service_as_Attack_Platform?_–_Krebs_on_Security.md
#  [*] Loading Cyber_Espionage_is_Alive_and_Well:_APT32_and_the_Threat_to_Global_Corporations_|_Mandiant.md
#  [*] Loading Fake_or_Fake:_Keeping_up_with_OceanLotus_decoys.md
#  [*] Loading Microsoft_Defender_Threat_Intelligence_|_Microsoft_Security.md
#  [*] Loading New_APT32_Malware_Campaign_Targets_Cambodian_Government.md
#  [*] Loading New_MacOS_Backdoor_Connected_to_OceanLotus_Surfaces.md
#  [*] Loading New_MacOS_Backdoor_Linked_to_OceanLotus_Found.md
#  [*] Loading OceanLotus:_Extending_Cyber_Espionage_Operations_Through_Fake_Websites_|_Volexity.md
#  [*] Loading OceanLotus:_New_watering_hole_attack_in_Southeast_Asia.md
#  [*] Loading OceanLotus:_macOS_malware_update.md
#  [*] Loading OceanLotus_APT_Uses_Steganography_to_Shroud_Payloads_|_Threatpost.md
#  [*] Loading OceanLotus_Blossoms:_Mass_Digital_Surveillance_and_Attacks_Targeting_ASEAN,_Asian_Nations,_the_Media,_Human_Rights_Groups,_and_Civil_Society_|_Volexity.md
#  [*] Loading OceanLotus_sets_sights_on_high-profile_targets_in_Southeast_Asia.md
#  [*] Loading Operation_Cobalt_Kitty:_A_large-scale_APT_in_Asia_carried_out_by_the_OceanLotus_Group.md
#  [*] Loading Report:_The_SpyRATs_of_OceanLotus.md
#  [*] Loading Threat_Spotlight:_Ratsnif_-_New_Network_Vermin_from_OceanLotus.md
#  [*] Loading Toyota_announces_second_security_breach_in_the_last_five_weeks_|_ZDNET.md
#  [*] Loading Tracking_OceanLotus’_new_Downloader,_KerrDown.md
#  [*] Loading Vietnamese_Threat_Actors_APT32_Targets_Wuhan_Government.md
#  [*] Loading Vietnamese_hackers_trigger_software_trap_after_Australian_sale_of_newspaper_in_Cambodia_-_ABC_News.md
#  [*] Loading __Page_not_found_-_Antiy_Labs_|__The_Next_Generation_Anti-Virus_Engine_Innovator_.md
#  [*] Loading malware-research_oceanlotus_at_master_·_eset_malware-research_·_GitHub.md
#  [*] Loading 奇安信威胁情报中心.md
#  [*] Loading APT33_Targets_Aerospace_&_Energy_Sectors_|_Spear_Phishing.md
#  [*] Loading APT_33,_Elfin,_Magnallium.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Elfin_Team_-_Wikipedia.md
#  [*] Loading Microsoft:_Hackers_target_defense_firms_with_new_FalseFont_malware.md
#  [*] Loading Obfuscated_APT33_C&Cs_Used_for_Narrow_Targeting.md
#  [*] Loading Peach_Sandstorm_password_spray_campaigns_enable_intelligence_collection_at_high-value_targets_|_Microsoft_Security_Blog.md
#  [*] Loading US_Cyber_Command_issues_alert_about_hackers_exploiting_Outlook_vulnerability_|_ZDNET.md
#  [*] Loading APT41_Resurfaces_as_Earth_Baku_With_New_Cyberespionage_Campaign.md
#  [*] Loading APT41_Targeting_U.S._State_Government_Networks_|_Mandiant.md
#  [*] Loading APT41_Using_New_Speculoos_Backdoor_to_Target_Organizations_Globally.md
#  [*] Loading APT41_World_Tour_2021_on_a_tight_schedule.md
#  [*] Loading APT_41.md
#  [*] Loading Access_Denied.md
#  [*] Loading BIOPASS_RAT_New_Malware_Sniffs_Victims_via_Live_Streaming.md
#  [*] Loading Big_airline_heist:_APT41_likely_behind_a_third-party_attack_on_Air_India.md
#  [*] Loading Drawing_a_Dragon:_Connecting_the_Dots_to_Find_APT41.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading GAME_OVER:_Detecting_and_Stopping_an_APT41_Operation_|_Mandiant.md
#  [*] Loading Gaming_industry_still_in_the_scope_of_attackers_in_Asia.md
#  [*] Loading Higaisa_or_Winnti?_APT41_backdoors,_old_and_new.md
#  [*] Loading Linux_Backdoor_RedXOR_Likely_Operated_by_Chinese_Nation-State.md
#  [*] Loading MESSAGETAP:_Who’s_Reading_Your_Text_Messages?_|_Mandiant.md
#  [*] Loading MoonBounce:_the_dark_side_of_UEFI_firmware_|_Securelist.md
#  [*] Loading No_“Game_over”_for_the_Winnti_Group.md
#  [*] Loading Operation_ShadowHammer:_new_supply_chain_attack_threatens_hundreds_of_thousands_of_users_worldwide_|_Kaspersky.md
#  [*] Loading PathFactory_-_Resource_Not_Found.md
#  [*] Loading Report:_Chinese_government_is_behind_a_decade_of_hacks_on_software_companies_|_Ars_Technica.md
#  [*] Loading ShadowPad:_How_Attackers_hide_Backdoor_in_Software_used_by_Hundreds_of_Large_Companies_around_the_World_|_Kaspersky.md
#  [*] Loading ShadowPad:_new_activity_from_the_Winnti_group.md
#  [*] Loading Some_ASUS_Updates_Drop_Backdoors_on_PCs_in_'Operation_ShadowHammer'_|_Threatpost.md
#  [*] Loading TeamViewer_Confirms_Undisclosed_Breach_From_2016.md
#  [*] Loading The_Origins_of_APT_41_and_ShadowPad_Lineage_-_CYFIRMA.md
#  [*] Loading The_SideWalk_may_be_as_dangerous_as_the_CROSSWALK.md
#  [*] Loading Winnti_Group's_skip-2.0:_A_Microsoft_SQL_Server_backdoor.md
#  [*] Loading Winnti_Group_targeting_universities_in_Hong_Kong.md
#  [*] Loading WyrmSpy_and_DragonEgg:_Lookout_Attributes_Android_Spyware_to_China’s_APT41_|_Lookout_Threat_Intelligence.md
#  [*] Loading You_never_walk_alone:_The_SideWalk_backdoor_gets_a_Linux_variant.md
#  [*] Loading APT_42.md
#  [*] Loading Iran:_State-Backed_Hacking_of_Activists,_Journalists,_Politicians_|_Human_Rights_Watch.md
#  [*] Loading AQUATIC_PANDA_in_Possession_of_Log4Shell_Exploit_Tools_|_CrowdStrike.md
#  [*] Loading Aquatic_Panda.md
#  [*] Loading AtlasCross.md
#  [*] Loading Warning:_Newly_Discovered_APT_Attacker_AtlasCross_Exploits_Red_Cross_Blood_Drive_Phishing_for_Cyberattack_-_NSFOCUS,_Inc.,_a_global_network_and_cyber_security_leader,_protects_enterprises_and_carriers_from_advanced_cyber_attacks..md
#  [*] Loading Access_Denied.md
#  [*] Loading Avalanche.md
#  [*] Loading Avalanche_(phishing_group)_-_Wikipedia.md
#  [*] Loading Page_not_found_|_PCWorld.md
#  [*] Loading AVIVORE.md
#  [*] Loading Accenture_|_Deutschland_|_Let_There_Be_Change.md
#  [*] Loading Axiom,_Group_72.md
#  [*] Loading Threat_Spotlight:_Group_72_-_Cisco_Blogs.md
#  [*] Loading Analysis_of_the_CloudWizard_APT_framework_|_Securelist.md
#  [*] Loading Bad_Magic,_RedStinger.md
#  [*] Loading Bad_magic:_new_APT_found_in_the_area_of_Russo-Ukrainian_conflict_|_Securelist.md
#  [*] Loading Uncovering_RedStinger_-_Undetected_APT_cyber_operations_in_Eastern_Europe_since_2020.md
#  [*] Loading 429_Error_|_ESET.md
#  [*] Loading APT_Bahamut_Attacks_Indian_Intelligence_Operative_using_Android_Malware_-_CYFIRMA.md
#  [*] Loading APT_Bahamut_Targets_Individuals_with_Android_Malware_Using_Spear_Messaging_-_CYFIRMA.md
#  [*] Loading BAHAMUT_Report.md
#  [*] Loading Bahamut,_Pursuing_a_Cyber_Espionage_Actor_in_the_Middle_East_-_bellingcat.md
#  [*] Loading Bahamut.md
#  [*] Loading Bahamut_Possibly_Responsible_for_Multi-Stage_Infection_Chain_Campaign_|_Anomali.md
#  [*] Loading Bahamut_Revisited,_More_Cyber_Espionage_in_the_Middle_East_and_South_Asia_-_bellingcat.md
#  [*] Loading Cyble_—_Bahamut_Android_Malware_returns_with_New_Spying_Capabilities.md
#  [*] Loading Cyble_—_Bahamut_Threat_Group_Targeting_Users_Through_Phishing_Campaign.md
#  [*] Loading 404:_Page_Not_Found_|_Forcepoint_.md
#  [*] Loading 404_Not_Found.md
#  [*] Loading Bamboo_Spider,_TA544.md
#  [*] Loading Criminals_in_a_festive_mood_–_Fox-IT_International_blog.md
#  [*] Loading GozNym_Banking_Trojan_Targeting_German_Banks_|_Threatpost.md
#  [*] Loading GozNym_Trojan_Attackers_Set_Sights_on_Europe,_Poland_|_Threatpost.md
#  [*] Loading GozNym_Trojan_targets_business_accounts_at_major_U.S._banks_|_Computerworld.md
#  [*] Loading IBM_Security_QRadar_EDR_-_Endpoint_Detection_and_Response_Solutions_.md
#  [*] Loading LinkedIn_information_used_to_spread_banking_malware_in_the_Netherlands_–_Fox-IT_International_blog.md
#  [*] Loading Meet_GozNym:_The_Banking_Malware_Offspring_of_Gozi_ISFB_and_Nymaim.md
#  [*] Loading Panda_Banker_Zeros_in_on_Japanese_Targets_|_NETSCOUT.md
#  [*] Loading Security_Brief:_TA544_Targets_Italian_Organizations_with_Ursnif_Malware_|_Proofpoint_US.md
#  [*] Loading TechCrunch_is_part_of_the_Yahoo_family_of_brands.md
#  [*] Loading Zeus_Sphinx_Back_in_Business:_Some_Core_Modifications_Arise.md
#  [*] Loading Zeus_Sphinx_Trojan_Awakens_Amidst_Coronavirus_Spam_Frenzy.md
#  [*] Loading Barium.md
#  [*] Loading Digitally_Signed_Malware_Targeting_Gaming_Companies.md
#  [*] Loading Access_Denied.md
#  [*] Loading BeagleBoyz.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Research,_News,_and_Perspectives.md
#  [*] Loading Access_Denied.md
#  [*] Loading Berserk_Bear,_Dragonfly_2.0.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Hackers_Have_Penetrated_Energy_Grid,_Symantec_Warns_|_Fortune.md
#  [*] Loading Big_Panda.md
#  [*] Loading CrowdStrike_Falcon_Traces_Attacks_Back_To_Hackers.md
#  [*] Loading Bismuth.md
#  [*] Loading Threat_actor_leverages_coin_miner_techniques_to_stay_under_the_radar_–_here’s_how_to_spot_them_|_Microsoft_Security_Blog.md
#  [*] Loading 360安全大脑.md
#  [*] Loading BITTER:_A_Targeted_Attack_Against_Pakistan_|_Forcepoint_.md
#  [*] Loading Bitter.md
#  [*] Loading Bitter_Group_Distributes_CHM_Malware_to_Chinese_Organizations_-_ASEC_BLOG.md
#  [*] Loading Cyble_—_Bitter_APT_group_using_"Dracarys"_Android_Spyware.md
#  [*] Loading Multiple_ArtraDownloader_Variants_Used_by_BITTER_to_Target_Pakistan.md
#  [*] Loading Suspected_BITTER_APT_Continues_Targeting_Government_of_China_and_Chinese_Organizations_|_Anomali.md
#  [*] Loading The_page_is_temporarily_unavailable.md
#  [*] Loading 404.md
#  [*] Loading Blackgear.md
#  [*] Loading Blackgear_Cyberespionage_Campaign_Resurfaces.md
#  [*] Loading BlackOasis.md
#  [*] Loading BlackOasis_APT_and_new_targeted_attacks_leveraging_zero-day_exploit_|_Securelist.md
#  [*] Loading FireEye_Uncovers_CVE-2017-8759:_Zero-Day_Used_in_the_Wild_to_Distribute_FINSPY_|_Mandiant.md
#  [*] Loading BendyBear:_Novel_Chinese_Shellcode_Linked_With_Cyber_Espionage_Group_BlackTech.md
#  [*] Loading BlackTech,_Circuit_Panda,_Radio_Panda.md
#  [*] Loading Plead_malware_distributed_via_MitM_attacks_at_router_level,_misusing_ASUS_WebStorage.md
#  [*] Loading Stolen_digital_certificates_misused_in_Plead_malware_campaign_discovered.md
#  [*] Loading These_hackers_have_spent_months_hiding_out_in_company_networks_undetected_|_ZDNET.md
#  [*] Loading Waterbear_Returns,_Uses_API_Hooking_to_Evade_Security.md
#  [*] Loading 360安全大脑.md
#  [*] Loading APT-C-36_Updates_Its_Long-term_Spam_Campaign_Against_South_American_Entities_With_Commodity_RATs.md
#  [*] Loading Blind_Eagle.md
#  [*] Loading Blind_Eagle_Deploys_Fake_UUE_Files_and_Fsociety_to_Target_Colombia's_Judiciary,_Financial,_Public,_and_Law_Enforcement_Entities.md
#  [*] Loading ____APT_Blind_Eagles_Malware_Arsenal_Technical_Analysis_|_ThreatMon
# .md
#  [*] Loading
# ________
# ____________Jamf_Threat_Labs_Discovers_Malware_from_BlueNoroff
# ________
# ____.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading
# 	Home_-_Broadcom_Community_-_Discussion_Forums,_Technical_Docs,_Ideas_and_Blogs
# .md
#  [*] Loading APT_trends_report_Q2_2020_|_Securelist.md
#  [*] Loading BAE_Systems_Threat_Research_Blog:_Taiwan_Heist:_Lazarus_Tools_and_Ransomware.md
#  [*] Loading Banco_de_Chile_Wiper_Attack_Just_a_Cover_for_$10M_SWIFT_Heist_|_Threatpost.md
#  [*] Loading Bloomberg_-_Are_you_a_robot?.md
#  [*] Loading BlueNoroff_introduces_new_methods_bypassing_MoTW_|_Securelist.md
#  [*] Loading Bluenoroff,_APT_38,_Stardust_Chollima.md
#  [*] Loading Bluenoroff’s_RustBucket_campaign_-_Sekoia.io_Blog.md
#  [*] Loading Lazarus_APT_Spinoff_Linked_to_Banking_Hacks_|_Threatpost.md
#  [*] Loading Microsoft:_BlueNoroff_hackers_plan_new_crypto-theft_attacks.md
#  [*] Loading New_BlueNoroff_loader_for_macOS_|_Securelist.md
#  [*] Loading North_Korean_Hacking_Group_Steals_$13.5_Million_From_Indian_Bank.md
#  [*] Loading North_Korean_hackers_infiltrate_Chile's_ATM_network_after_Skype_job_interview_|_ZDNET.md
#  [*] Loading North_Korean_hackers_spoof_venture_capital_firms_in_Japan,_Vietnam_and_US.md
#  [*] Loading TA444:_APT_Startup_Aimed_at_Acquisition_(of_Your_Funds)_|_Proofpoint_US.md
#  [*] Loading The_BlueNoroff_cryptocurrency_hunt_is_still_on_|_Securelist.md
#  [*] Loading The_DPRK_strikes_using_a_new_variant_of_RUSTBUCKET_—_Elastic_Security_Labs.md
#  [*] Loading Vietnamese_Bank_Blocks_$1_Million_SWIFT_Heist.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading Blue_Termite,_Cloudy_Omega.md
#  [*] Loading New_activity_of_the_Blue_Termite_APT_|_Securelist.md
#  [*] Loading Attack_Campaign_on_the_Government_of_Thailand_Delivers_Bookworm_Trojan.md
#  [*] Loading Bookworm.md
#  [*] Loading Bookworm_Trojan:_A_Model_of_Modular_Architecture.md
#  [*] Loading Boson_Spider.md
#  [*] Loading CoreBot_banking_trojan_malware_returns_after_two-year_break_|_ZDNET.md
#  [*] Loading Watch_Out_for_CoreBot,_New_Stealer_Malware_in_the_Wild.md
#  [*] Loading An_In-Depth_Analysis_of_Samsam_Ransomware_and_BOSS_SPIDER.md
#  [*] Loading Boss_Spider,_Gold_Lowell.md
#  [*] Loading SamSam_Ransomware_Campaigns_|_Secureworks.md
#  [*] Loading Boulder_Bear.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading Additional_Activities_of_the_Tick_Group_That_Attacks_with_a_Modified_Q-Dir_and_Their_Ties_with_Operation_Triple_Tiang_-_ASEC_BLOG.md
#  [*] Loading BRONZE_BUTLER__Hacker_Group_Targets_Japanese_Enterprises_|_Secureworks.md
#  [*] Loading Bronze_Butler,_Tick,_RedBaldNight,_Stalker_Panda.md
#  [*] Loading Exchange_servers_under_siege_from_at_least_10_APT_groups.md
#  [*] Loading Mitsubishi_Electric_discloses_security_breach,_China_is_main_suspect_|_ZDNET.md
#  [*] Loading REDBALDKNIGHT’s_Daserf_Backdoor_Now_Uses_Steganography.md
#  [*] Loading ShadowWali:_New_variant_of_the_xxmm_family_of_backdoors.md
#  [*] Loading Tick_Group_Weaponized_Secure_USB_Drives_to_Target_Air-Gapped_Critical_Systems.md
#  [*] Loading “Tick”_Group_Continues_Attacks.md
#  [*] Loading Bronze_Highland.md
#  [*] Loading Chinese_APT_group_targets_India_and_Hong_Kong_using_new_variant_of_MgBot_malware_|_Malwarebytes_Labs.md
#  [*] Loading Cyber_Threat_Group_Profiles:_Their_Objectives,_Aliases,_and_Malware_Tools_|_Secureworks.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Evasive_Panda_APT_group_delivers_malware_via_updates_for_popular_Chinese_software.md
#  [*] Loading BRONZE_STARLIGHT_Ransomware_Operations_Use_HUI_Loader_|_Secureworks.md
#  [*] Loading Bronze_Starlight.md
#  [*] Loading Chinese_Entanglement_|_DLL_Hijacking_in_the_Asian_Gambling_Sector_-_SentinelOne.md
#  [*] Loading Cyber_Threat_Group_Profiles:_Their_Objectives,_Aliases,_and_Malware_Tools_|_Secureworks.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading 404:_Page_Not_Found_|_Forcepoint_.md
#  [*] Loading 429_Error_|_ESET.md
#  [*] Loading Buhtrap,_Ratopak_Spider.md
#  [*] Loading Buhtrap_group_uses_zero-day_in_latest_espionage_campaigns.md
#  [*] Loading Operation_Buhtrap_malware_distributed_via_ammyy.com.md
#  [*] Loading Spike_Buhtrap_and_RTM_financial_Trojan_activity_|_Kaspersky_official_blog.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading Cadelle.md
#  [*] Loading Cadet_Blizzard.md
#  [*] Loading Cadet_Blizzard_emerges_as_a_novel_and_distinct_Russian_threat_actor_|_Microsoft_Security_Blog.md
#  [*] Loading Destructive_malware_targeting_Ukrainian_organizations_|_Microsoft_Security_Blog.md
#  [*] Loading Callisto_Group.md
#  [*] Loading Not_found_|_F‑Secure.md
#  [*] Loading 4_Chinese_APT_Groups_Identified_Targeting_Mail_Server_of_Afghan_Telecommunications_Firm_Roshan.md
#  [*] Loading Calypso.md
#  [*] Loading Calypso_APT:_new_group_attacking_state_institutions.md
#  [*] Loading Exchange_servers_under_siege_from_at_least_10_APT_groups.md
#  [*] Loading BlackMatter_ransomware_hits_medical_technology_giant_Olympus.md
#  [*] Loading BlackMatter_ransomware_moves_victims_to_LockBit_after_shutdown.md
#  [*] Loading BlackMatter_ransomware_targets_companies_with_revenue_of_$100_million_and_more.md
#  [*] Loading Canadian_retailer_Home_Hardware_hit_by_ransomware_|_Financial_Post.md
#  [*] Loading Carbanak,_Anunak.md
#  [*] Loading Chemical_distributor_pays_$4.4_million_to_DarkSide_ransomware.md
#  [*] Loading CompuCom_MSP_hit_by_DarkSide_ransomware_cyberattack.md
#  [*] Loading DarkSide:_New_targeted_ransomware_demands_million_dollar_ransoms.md
#  [*] Loading DarkSide_Ransomware_hits_North_American_real_estate_developer.md
#  [*] Loading DarkSide_ransomware_gang_moves_some_of_its_Bitcoin_after_REvil_got_hit_by_law_enforcement.md
#  [*] Loading Darkside_Ransomware_Gang_Launches_Affiliate_Program.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Eletrobras,_Copel_energy_companies_hit_by_ransomware_attacks.md
#  [*] Loading FBI:_FIN7_hackers_target_US_companies_with_BadUSB_devices_to_install_ransomware.md
#  [*] Loading Fashion_retailer_Guess_discloses_data_breach_after_ransomware_attack.md
#  [*] Loading Largest_U.S._pipeline_shuts_down_operations_after_ransomware_attack.md
#  [*] Loading Leading_Canadian_rental_car_company_hit_by_DarkSide_ransomware.md
#  [*] Loading Linux_version_of_BlackMatter_ransomware_targets_VMware_ESXi_servers.md
#  [*] Loading Marketron_marketing_services_hit_by_Blackmatter_ransomware.md
#  [*] Loading Microsoft:_Notorious_FIN7_hackers_return_in_Clop_ransomware_attacks.md
#  [*] Loading New_Ransomware_Tactic:_Adversaries_Target_ESXi_Servers_|_CrowdStrike.md
#  [*] Loading Ransomware_gang_donates_part_of_ransom_demands_to_charity_organizations_|_ZDNET.md
#  [*] Loading Ransomware_gang_wants_to_short_the_stock_price_of_their_victims.md
#  [*] Loading Toshiba_Tech_France_says_it_has_been_hacked_by_DarkSide.md
#  [*] Loading US_chemical_distributor_shares_info_on_DarkSide_ransomware_data_theft.md
#  [*] Loading US_farmer_cooperative_hit_by_$5.9M_BlackMatter_ransomware_attack.md
#  [*] Loading Carderbee.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading APT_Trends_report_Q1_2018_|_Securelist.md
#  [*] Loading CardinalLizard.md
#  [*] Loading Careto,_The_Mask.md
#  [*] Loading The_Careto_Mask_APT:_Frequently_Asked_Questions_|_Securelist.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading APT39_|_Iranian_Threat_Group_Focused_on_Personal_Information.md
#  [*] Loading Chafer,_APT_39.md
#  [*] Loading Chafer_used_Remexi_malware_to_spy_on_Iran-based_foreign_diplomatic_entities_|_Securelist.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading New_Python-Based_Payload_MechaFlounder_Used_by_Chafer.md
#  [*] Loading Observations_of_ITG07_Cyber_Operations.md
#  [*] Loading ChamelGang.md
#  [*] Loading ChamelGang_and_ChamelDoH:_A_DNS-over-HTTPS_implant_—_Stairwell.md
#  [*] Loading Masters_of_Mimicry:_new_APT_group_ChamelGang_and_its_arsenal.md
#  [*] Loading Chimera.md
#  [*] Loading Hackers_spent_2+_years_looting_secrets_of_chipmaker_NXP_before_being_detected_|_Ars_Technica.md
#  [*] Loading Page_not_found_–_Fox-IT_International_blog.md
#  [*] Loading CIA.md
#  [*] Loading Central_Intelligence_Agency_-_Wikipedia.md
#  [*] Loading Elite_CIA_hacking_unit_failed_to_protect_its_systems,_allowing_disclosure_to_WikiLeaks_-_The_Washington_Post.md
#  [*] Loading Swiss_report_reveals_new_details_on_CIA_spying_operation_-_The_Washington_Post.md
#  [*] Loading Yahoo_maakt_deel_uit_van_de_Yahoo-merkenfamilie.md
#  [*] Loading Circles.md
#  [*] Loading Running_in_Circles:_Uncovering_the_Clients_of_Cyberespionage_Firm_Circles_-_The_Citizen_Lab.md
#  [*] Loading Chainalysis_in_Action:_U.S._Authorities_Disrupt_NetWalker_Ransomware_-_Chainalysis.md
#  [*] Loading Circus_Spider.md
#  [*] Loading Enel_Group_hit_by_ransomware_again,_Netwalker_demands_$14_million.md
#  [*] Loading Equinix_data_center_giant_hit_by_Netwalker_Ransomware,_$4.5M_ransom.md
#  [*] Loading Michigan_State_University_hit_by_ransomware_gang_|_ZDNET.md
#  [*] Loading Netwalker_Ransomware_Infecting_Users_via_Coronavirus_Phishing.md
#  [*] Loading Netwalker_ransomware_continues_assault_on_US_colleges,_hits_UCSF.md
#  [*] Loading Netwalker_ransomware_hits_Argentinian_government,_demands_$4_million.md
#  [*] Loading Netwalker_ransomware_hits_Pakistan's_largest_private_power_utility.md
#  [*] Loading Philadelphia-area_health_system_says_it_'isolated'_a_malware_attack_|_CyberScoop.md
#  [*] Loading Ransomware_Attack_Hinders_Toll_Group_Operations_|_Threatpost.md
#  [*] Loading Ransomware_recruits_affiliates_with_huge_payouts,_automated_leaks.md
#  [*] Loading Spanish_hospitals_targeted_with_coronavirus-themed_phishing_lures_in_Netwalker_ransomware_attacks.md
#  [*] Loading Sucuri_WebSite_Firewall_-_Access_Denied.md
#  [*] Loading TechCrunch_is_part_of_the_Yahoo_family_of_brands.md
#  [*] Loading Threat_Analysis_Unit_(TAU)_Threat_Intelligence_Notification:_MailTo_(NetWalker)_Ransomware_-_VMware_Security_Blog_-_VMware.md
#  [*] Loading Clever_Kitten.md
#  [*] Loading Clever_Kitten_|_Threat_Actor_Profile_|_CrowdStrike.md
#  [*] Loading Clockwork_Spider.md
#  [*] Loading Cobalt_Group.md
#  [*] Loading Cobalt_Strikes_Again,_Spam_Runs_Target_Russian_Banks.md
#  [*] Loading Cybercriminals_Increasingly_Trying_to_Ensnare_the_Big_Financial_Fish_|_Secureworks.md
#  [*] Loading Cybersecurity_Services,_Solutions_&_Products._Global_Provider_|_Group-IB.md
#  [*] Loading Magecart_Group_4:_A_link_with_Cobalt_Group?_|_Malwarebytes_Labs.md
#  [*] Loading Microsoft_Defender_Threat_Intelligence_|_Microsoft_Security.md
#  [*] Loading Microsoft_Word_Intruder_Integrates_CVE-2017-0199,_Utilized_by_Cobalt_Group_to_Target_Financial_Institutions_|_Proofpoint_US.md
#  [*] Loading New_Techniques_to_Uncover_and_Attribute_Cobalt_Gang_Commodity_Builders_and_Infrastructure_Revealed.md
#  [*] Loading Blue_Callisto_orbits_around_US_Laboratories_in_2022
# .md
#  [*] Loading Cold_River.md
#  [*] Loading Russian_FSB_Cyber_Actor_Star_Blizzard_Continues_Worldwide_Spear-phishing_Campaigns_|_CISA.md
#  [*] Loading Tracking_cyber_activity_in_Eastern_Europe.md
#  [*] Loading Update_on_cyber_activity_in_Eastern_Europe.md
#  [*] Loading VMware_NSX_Security_Solutions.md
#  [*] Loading
# 	Endpoint_Protection_-_Symantec_Enterprise
# .md
#  [*] Loading Comment_Crew,_APT_1.md
#  [*] Loading Hackers_Plundered_Israeli_Defense_Firms_that_Built_‘Iron_Dome’_Missile_Defense_System_–_Krebs_on_Security.md
#  [*] Loading PLA_Unit_61398_-_Wikipedia.md
#  [*] Loading The_Full_Story_of_the_Stunning_RSA_Hack_Can_Finally_Be_Told_|_WIRED.md
#  [*] Loading The_Siesta_Campaign:_A_New_Targeted_Attack_Awakens.md
#  [*] Loading Confucius.md
#  [*] Loading Confucius_Says...Malware_Families_Get_Further_By_Abusing_Legitimate_Websites.md
#  [*] Loading Confucius_Update:_New_Techniques,_More_Patchwork_Links.md
#  [*] Loading Confucius_Uses_Pegasus_Spyware-related_Lures_to_Target_Pakistani_Military.md
#  [*] Loading Deciphering_Confucius’_Cyberespionage_Operations.md
#  [*] Loading Recent_InPage_Exploits_Lead_to_Multiple_Malware_Families.md
#  [*] Loading CopyKittens,_Slayer_Kitten.md
#  [*] Loading 429_Error_|_ESET.md
#  [*] Loading Corkow,_Metel.md
#  [*] Loading Metel_Banking_Trojan_-_ATM_Balance_Rollbacks.md
#  [*] Loading Corsair_Jackal.md
#  [*] Loading Research_&_Threat_Intel_Archives_-_crowdstrike.com.md
#  [*] Loading CostaRicto.md
#  [*] Loading The_CostaRicto_Campaign:_Cyber-Espionage_Outsourced.md
#  [*] Loading Covellite.md
#  [*] Loading Your_first_line_of_defense_against_adversaries_|_Dragos.md
#  [*] Loading Cron.md
#  [*] Loading Cron_has_fallen.md
#  [*] Loading New_version_of_mobile_malware_Catelites_possibly_linked_to_Cron_cyber_gang.md
#  [*] Loading Curious_Gorge.md
#  [*] Loading Tracking_cyber_activity_in_Eastern_Europe.md
#  [*] Loading Update_on_cyber_activity_in_Eastern_Europe.md
#  [*] Loading Cutting_Kitten,_TG-2889.md
#  [*] Loading Page_Not_Found.md
#  [*] Loading Suspected_Hacker_Group_Creates_Network_of_Fake_LinkedIn_Profiles_|_Secureworks.md
#  [*] Loading CyberAv3ngers.md
#  [*] Loading IRGC-Affiliated_Cyber_Actors_Exploit_PLCs_in_Multiple_Sectors,_Including_U.S._Water_and_Wastewater_Systems_Facilities_|_CISA.md
#  [*] Loading Pennsylvania_water_authority_hit_with_cyberattack_allegedly_tied_to_pro-Iran_group.md
#  [*] Loading Two-day_water_outage_in_remote_Irish_region_caused_by_pro-Iran_hackers.md
#  [*] Loading 'Cyber_Berkut'_Hackers_Target_Major_Ukrainian_Bank.md
#  [*] Loading CyberBerkut_-_Wikipedia.md
#  [*] Loading Cyber_Berkut.md
#  [*] Loading Cyber_Berkut_Graduates_From_DDoS_Stunts_to_Purveyor_of_Cyber_Attack_Tools.md
#  [*] Loading Nato_websites_disabled_by_cyber_attack_on_eve_of_Crimea_vote.md
#  [*] Loading Australian_airport_website_hacked_by_Islamic_State.md
#  [*] Loading Cyber_Caliphate_Army_(CCA),_United_Cyber_Caliphate_(UCC).md
#  [*] Loading How_France's_TV5_was_almost_destroyed_by_'Russian_hackers'_-_BBC_News.md
#  [*] Loading ISIS-linked_Cyber_Group_Releases_'Kill_List'_of_8,786_US_Targets_For_Lone_Wolf_Attacks.md
#  [*] Loading ISIS_'kill_list'_includes_names_of_151_Canadians_|_CBC_News.md
#  [*] Loading ISIS_hackers_intercept_top_secret_British_Government_emails_in_major_security_breach_uncovered_by_GCHQ_-_Mirror_Online.md
#  [*] Loading Isis_'hacking_division'_releases_details_of_1,400_Americans_and_urges_attacks_|_Islamic_State_|_The_Guardian.md
#  [*] Loading Islamic_State_Hacking_Division_-_Wikipedia.md
#  [*] Loading Russian_hackers_posed_as_IS_to_threaten_military_wives_|_AP_News.md
#  [*] Loading Cyber_fighters_of_Izz_Ad-Din_Al_Qassam,_Fraternal_Jackal.md
#  [*] Loading Dancho_Danchev's_Blog:_Dissecting_'Operation_Ababil'_-_an_OSINT_Analysis.md
#  [*] Loading Izz_ad-Din_al-Qassam_Cyber_Fighters_–_Krebs_on_Security.md
#  [*] Loading Operation_Ababil_-_Wikipedia.md
#  [*] Loading The_Rise_And_Fall_Of_The_Qassam_Cyber_Fighters:_Arab_Hacking_Group_or_Iranian_Cyber_Front?_A_Review_Of_Its_First_Year_Of_Activity_–_September_2012-September_2013_|_MEMRI.md
#  [*] Loading Dalbit.md
#  [*] Loading Dalbit_(m00nlight):_Chinese_Hacker_Group's_APT_Attack_Campaign_-_ASEC_BLOG.md
#  [*] Loading Dark_Basin.md
#  [*] Loading Dark_Basin:_Uncovering_a_Massive_Hack-For-Hire_Operation_-_The_Citizen_Lab.md
#  [*] Loading NortonLifeLock_Blogs.md
#  [*] Loading Dark_Caracal.md
#  [*] Loading Cybersecurity_Services,_Solutions_&_Products._Global_Provider_|_Group-IB.md
#  [*] Loading DarkCasino.md
#  [*] Loading Operation_DarkCasino:_In-Depth_Analysis_of_Attacks_by_APT_Group_Evilnum_(Part_1)_-_NSFOCUS,_Inc.,_a_global_network_and_cyber_security_leader,_protects_enterprises_and_carriers_from_advanced_cyber_attacks..md
#  [*] Loading Operation_DarkCasino:_In-Depth_Analysis_of_Attacks_by_APT_Group_Evilnum_(Part_2)_-_NSFOCUS,_Inc.,_a_global_network_and_cyber_security_leader,_protects_enterprises_and_carriers_from_advanced_cyber_attacks..md
#  [*] Loading The_New_APT_Group_DarkCasino_and_the_Global_Surge_in_WinRAR_0-Day_Exploits_-_NSFOCUS,_Inc.,_a_global_network_and_cyber_security_leader,_protects_enterprises_and_carriers_from_advanced_cyber_attacks..md
#  [*] Loading 360_向广大政企用户发出_Win7_漏洞威胁预警通告_|_极客公园.md
#  [*] Loading Analysis_of_CVE-2018-8174_VBScript_0day_and_APT_actor_related_to_Office_targeted_attack_|_360_Total_Security_Blog.md
#  [*] Loading Bitdefender_Labs.md
#  [*] Loading COVID-19_Themes_Are_Being_Utilized_by_Threat_Actors_of_Varying_Sophistication_|_Anomali.md
#  [*] Loading DarkHotel.md
#  [*] Loading Darkhotel's_attacks_in_2015_|_Securelist.md
#  [*] Loading Darkhotel_APT_is_back:_Zero-day_vulnerability_in_Microsoft_VBScript_is_exploited_|_360_Total_Security_Blog.md
#  [*] Loading New_DarkHotel_APT_attack_chain_identified_|_Zscaler.md
#  [*] Loading New_LNK_attack_tied_to_Higaisa_APT_discovered_|_Malwarebytes_Labs.md
#  [*] Loading New_Malicious_Networks_Discovered_in_Dark_Hotel_Malware_Campaign_|_Recorded_Future.md
#  [*] Loading Not_Found_–_Medium.md
#  [*] Loading Operation_PowerFall:_CVE-2020-0986_and_variants_|_Securelist.md
#  [*] Loading Ramsay:_A_cyber-espionage_toolkit_tailored_for_air-gapped_networks.md
#  [*] Loading DarkHydrus,_LazyMeerkat.md
#  [*] Loading DarkHydrus_Uses_Phishery_to_Harvest_Credentials_in_the_Middle_East.md
#  [*] Loading DarkHydrus_delivers_new_Trojan_that_can_use_Google_Drive_for_C2_communications.md
#  [*] Loading New_Threat_Actor_Group_DarkHydrus_Targets_Middle_East_Government.md
#  [*] Loading Cybersecurity_Services,_Solutions_&_Products._Global_Provider_|_Group-IB.md
#  [*] Loading Dark_Pink.md
#  [*] Loading Dark_Pink_APT_Group_Strikes_Government_Entities_in_South_Asian_Countries.md
#  [*] Loading DarkUniverse.md
#  [*] Loading The_DarkUniverse:_mysterious_APT_framework_#27_|_Securelist.md
#  [*] Loading APT_trends_report_Q2_2020_|_Securelist.md
#  [*] Loading DeathStalker_targets_legal_entities_with_new_Janicab_variant_|_Securelist.md
#  [*] Loading Deceptikons,_DeathStalker.md
#  [*] Loading Lifting_the_veil_on_DeathStalker,_a_mercenary_triumvirate_|_Securelist.md
#  [*] Loading VileRAT:_DeathStalker’s_continuous_strike_at_foreign_and_cryptocurrency_exchanges_|_Securelist.md
#  [*] Loading What_did_DeathStalker_hide_between_two_ferns?_|_Securelist.md
#  [*] Loading APT-C-23_group_evolves_its_Android_spyware.md
#  [*] Loading Arid_Viper_|_APT’s_Nest_of_SpyC23_Malware_Continues_to_Target_Android_Devices_-_SentinelOne.md
#  [*] Loading Breaking_The_Weakest_Link_Of_The_Strongest_Chain_|_Securelist.md
#  [*] Loading Desert_Falcons.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading FrozenCell:_Multi-Platform_Surveillance_Against_Palestinians_|_Lookout_Threat_Intelligence.md
#  [*] Loading New_GnatSpy_Mobile_Malware_Family_Discovered.md
#  [*] Loading New_Surveillanceware_in_Google_Play_Targeting_Middle_East_|_Lookout_Threat_Intelligence.md
#  [*] Loading New_Variants_of_Android_Spyware_Linked_to_APT_C-23_Enhanced_for_Stealth_and_Persistence,_Sophos_Research_Reveals_|_Sophos.md
#  [*] Loading Operation_Arid_Viper_Slithers_Back_into_View_|_Proofpoint_US.md
#  [*] Loading Operation_Bearded_Barbie:_APT-C-23_Campaign_Targeting_Israeli_Officials.md
#  [*] Loading Page_not_found_|_ThreatConnect.md
#  [*] Loading PyMICROPSIA:_New_Information-Stealing_Trojan_from_AridViper.md
#  [*] Loading Acer_confirms_second_security_breach_this_year.md
#  [*] Loading Desorden.md
#  [*] Loading Threat_Group_‘Desorden’_Actively_Targeting_Asian_Conglomerates_|_Threat_Intelligence_|_CloudSEK.md
#  [*] Loading DEV-0270,_Nemesis_Kitten.md
#  [*] Loading Profiling_DEV-0270:_PHOSPHORUS’_ransomware_operations_|_Microsoft_Security_Blog.md
#  [*] Loading Dextorous_Spider.md
#  [*] Loading Dizzy_Panda.md
#  [*] Loading DNSpionage.md
#  [*] Loading DNSpionage_–_Krebs_on_Security.md
#  [*] Loading Global_DNS_Hijacking_Campaign:_DNS_Record_Manipulation_at_Scale_|_Mandiant.md
#  [*] Loading Widespread_DNS_Hijacking_Activity_Targets_Multiple_Sectors.md
#  [*] Loading Domestic_Kitten.md
#  [*] Loading Domestic_Kitten_campaign_spying_on_Iranian_citizens_with_new_FurBall_malware.md
#  [*] Loading Mobile_Campaign_‘Bouncing_Golf’_Affects_Middle_East.md
#  [*] Loading 360安全大脑.md
#  [*] Loading APT-C-35:_New_Windows_Framework_Revealed.md
#  [*] Loading DoNot_APT_Elevates_its_Tactics_by_Deploying_Malicious_Android_Apps_on_Google_Play_Store_-_CYFIRMA.md
#  [*] Loading DoNot_Go!_Do_not_respawn!.md
#  [*] Loading Donot_Team.md
#  [*] Loading Donot_Team_Leverages_New_Framework.md
#  [*] Loading Microsoft_Defender_Threat_Intelligence_|_Microsoft_Security.md
#  [*] Loading Compal,_the_second-largest_laptop_manufacturer_in_the_world,_hit_by_ransomware_|_ZDNET.md
#  [*] Loading CrowdStrike_Discovers_New_DoppelPaymer_Ransomware_&_Dridex_Variant.md
#  [*] Loading DoppelPaymer_Ransomware_Sells_Victims'_Data_on_Darknet_if_Not_Paid.md
#  [*] Loading DoppelPaymer_ransomware_gang_rebrands_as_the_Grief_group.md
#  [*] Loading DoppelPaymer_ransomware_hits_Newcastle_University,_leaks_data.md
#  [*] Loading Doppel_Spider.md
# ...
#  [*] Loading Sphinx_Moth:_Expanding_our_knowledge_of_the_“Wild_Neutron”___“Morpho”_APT_–_Kudelski_Security_Research.md
#  [*] Loading Update_Your_Browser_|_Facebook.md
#  [*] Loading Wild_Neutron,_Butterfly,_Sphinx_Moth.md
#  [*] Loading Wild_Neutron_–_Economic_espionage_threat_actor_returns_with_new_tricks_|_Securelist.md
#  [*] Loading WildPressure.md
#  [*] Loading WildPressure_targets_industrial-related_entities_in_the_Middle_East_|_Securelist.md
#  [*] Loading WildPressure_targets_macOS_|_Securelist.md
#  [*] Loading Shifting_in_the_Wind:_WINDSHIFT_Attacks_Target_Middle_Eastern_Governments.md
#  [*] Loading WindShift.md
#  [*] Loading 403_Forbidden.md
#  [*] Loading Bayer_hit_by_cyberattack_–_DW_–_04_04_2019.md
#  [*] Loading Examining_a_Possible_Member_of_the_Winnti_Group.md
#  [*] Loading Exchange_servers_under_siege_from_at_least_10_APT_groups.md
#  [*] Loading Games_are_over_|_Securelist.md
#  [*] Loading Hackers_steal_Thyssenkrupp_secrets_–_DW_–_12_08_2016.md
#  [*] Loading Investigativ_Berichterstattung_und_Reportagen_|_tagesschau.de.md
#  [*] Loading WINNTI_GROUP:_Insights_From_the_Past_-_QuoIntelligence.md
#  [*] Loading Winnti._More_than_just_a_game_|_Securelist.md
#  [*] Loading Winnti:_Attacking_the_Heart_of_the_German_Industry.md
#  [*] Loading Winnti:_More_than_just_Windows_and_Gates_|_by_Chronicle_|_Chronicle_Blog_|_Medium.md
#  [*] Loading Winnti_Abuses_GitHub_for_C&C_Communications.md
#  [*] Loading Winnti_Group,_Blackfly,_Wicked_Panda.md
#  [*] Loading 429_Error_|_ESET.md
#  [*] Loading Winter_Vivern.md
#  [*] Loading Winter_Vivern_Uses_Zimbra_Vulnerability_to_Target_NATO_Email_|_Proofpoint_US.md
#  [*] Loading Winter_Vivern_|_Uncovering_a_Wave_of_Global_Espionage_-_SentinelOne.md
#  [*] Loading Winter_Vivern_–_all_Summer.md
#  [*] Loading Zimbra_0-day_used_to_target_international_government_organizations.md
#  [*] Loading WIP26.md
#  [*] Loading WIP26_Espionage_|_Threat_Actors_Abuse_Cloud_Infrastructure_in_Targeted_Telco_Attacks_-_SentinelOne.md
#  [*] Loading Public_report_on_attacks_in_Middle_East_we_attribute_to_WIRTE_APT_|_Securelist.md
#  [*] Loading WIRTE_Group.md
#  [*] Loading WIRTE_Group_attacking_the_Middle_East.md
#  [*] Loading "Sin”-ful_SPIDERS:_WIZARD_SPIDER_and_LUNAR_SPIDER_Sharing_the_Same_Web.md
#  [*] Loading An_Inside_Look_at_the_Conti_Group_|_Deep_Instinct.md
#  [*] Loading Anchor_Project_|_The_Deadly_Planeswalker:_How_The_TrickBot_Group_United_High-Tech_Crimeware_&_APT_-_SentinelLabs.md
#  [*] Loading BazaFlix:_BazaLoader_Fakes_Movie_Streaming_Service_|_Proofpoint_US.md
#  [*] Loading BazarBackdoor:_TrickBot_gang’s_new_stealthy_network-hacking_malware.md
#  [*] Loading BazarLoader_deploys_a_pair_of_novel_spam_vectors_–_Sophos_News.md
#  [*] Loading Bitdefender_Labs.md
#  [*] Loading Celebrity_jewelry_house_Graff_falls_victim_to_ransomware.md
#  [*] Loading City_of_Liege,_Belgium_hit_by_ransomware.md
#  [*] Loading Conti_(Ryuk)_joins_the_ranks_of_ransomware_gangs_operating_data_leak_sites_|_ZDNET.md
#  [*] Loading Conti_Ransom_Gang_Starts_Selling_Access_to_Victims_–_Krebs_on_Security.md
#  [*] Loading Conti_Ransomware:_Inside_the_Infamous_RaaS_Group_|_Flashpoint.md
#  [*] Loading Conti_and_Karma_actors_attack_healthcare_provider_at_same_time_through_ProxyShell_exploits_–_Sophos_News.md
#  [*] Loading Conti_gang_threatens_to_dump_victim_data_if_ransom_negotiations_leak_to_reporters.md
#  [*] Loading Conti_ransomware_also_targeted_Ireland's_Department_of_Health.md
#  [*] Loading Conti_ransomware_claims_to_have_hacked_Peru_MOF_-_Dirección_General_de_Inteligencia_(DIGIMIN).md
#  [*] Loading Conti_ransomware_gives_HSE_Ireland_free_decryptor,_still_selling_data.md
#  [*] Loading Conti_ransomware_group's_pulse_stops,_but_did_it_fake_its_own_death?.md
#  [*] Loading Conti_ransomware_hits_Apple,_Tesla_supplier.md
#  [*] Loading Conti_ransomware_prioritizes_revenue_and_cyberinsurance_data_theft.md
#  [*] Loading Cybercriminals_Spoof_Major_Accounting_and_Payroll_Firms_in_Tax_Season_Malware_Campaigns.md
#  [*] Loading Cybersecurity_Services,_Solutions_&_Products._Global_Provider_|_Group-IB.md
#  [*] Loading DOD_contractor_suffers_ransomware_infection_|_ZDNET.md
#  [*] Loading Data_breach_impacts_80,000_South_Australian_govt_employees.md
#  [*] Loading Diavol_-_A_New_Ransomware_Used_By_Wizard_Spider?_|_Fortinet.md
#  [*] Loading ERROR:_The_request_could_not_be_satisfied.md
#  [*] Loading Engineering_firm_Parker_discloses_data_breach_after_ransomware_attack.md
#  [*] Loading Epiq_Global_Down_As_Company_Investigates_Unauthorized_Activity_on_Systems_|_LawSites.md
#  [*] Loading Exagrid_pays_$2.6m_to_Conti_ransomware_attackers_|_Computer_Weekly.md
#  [*] Loading FatFace_sends_controversial_data_breach_email_after_ransomware_attack.md
#  [*] Loading Fight_cyber_threats_—_and_win_|_Intel471.md
#  [*] Loading French_IT_giant_Sopra_Steria_hit_by_Ryuk_ransomware.md
#  [*] Loading GOLD_ULRICK_continues_Conti_operations_despite_public_disclosures__|_Secureworks.md
#  [*] Loading GOLD_ULRICK_leaks_reveal_organizational_structure_and_relationships__|_Secureworks.md
#  [*] Loading Goodbye_Mworm,_Hello_Nworm:_TrickBot_Updates_Propagation_Module.md
#  [*] Loading Indonesia's_central_bank_confirms_ransomware_attack,_Conti_leaks_data.md
#  [*] Loading JVCKenwood_hit_by_Conti_ransomware_claiming_theft_of_1.5TB_data.md
#  [*] Loading K12_online_schooling_giant_pays_Ryuk_ransomware_to_stop_data_leak.md
#  [*] Loading KP_Snacks_giant_hit_by_Conti_ransomware,_deliveries_disrupted.md
#  [*] Loading Leading_toy_maker_Mattel_hit_by_ransomware.md
#  [*] Loading LightBot:_TrickBot’s_new_reconnaissance_malware_for_high-value_targets.md
#  [*] Loading Louisiana_was_hit_by_Ryuk,_triggering_another_cyber-emergency_|_Ars_Technica.md
#  [*] Loading Marketing_giant_RRD_confirms_data_theft_in_Conti_ransomware_attack.md
#  [*] Loading McMenamins_breweries_hit_by_a_Conti_ransomware_attack.md
#  [*] Loading New_Evidence_Proves_Ongoing_WIZARD_LUNAR_SPIDER_Collaboration.md
#  [*] Loading New_Orleans_latest_apparent_victim_of_Ryuk_ransomware_|_StateScoop.md
#  [*] Loading New_Variant_of_TrickBot_Being_Spread_by_Word_Document_|_FortiGuard_Labs.md
#  [*] Loading New_Zealand_hospitals_infected_by_ransomware,_cancel_some_surgeries_•_The_Register.md
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 8
#       6     print(f' [*] Loading {os.path.basename(group)}')
#       7     loader = UnstructuredMarkdownLoader(group)
# ----> 8     md_docs.extend(loader.load())
#      10 print(f'[+] Number of .md documents processed: {len(md_docs)}')
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langchain_core/document_loaders/base.py:29, in BaseLoader.load(self)
#      27 def load(self) -> List[Document]:
#      28     """Load data into Document objects."""
# ---> 29     return list(self.lazy_load())
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langchain_community/document_loaders/unstructured.py:87, in UnstructuredBaseLoader.lazy_load(self)
#      85 def lazy_load(self) -> Iterator[Document]:
#      86     """Load file."""
# ---> 87     elements = self._get_elements()
#      88     self._post_process_elements(elements)
#      89     if self.mode == "elements":
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langchain_community/document_loaders/markdown.py:45, in UnstructuredMarkdownLoader._get_elements(self)
#      39 if unstructured_version < (0, 4, 16):
#      40     raise ValueError(
#      41         f"You are on unstructured version {__unstructured_version__}. "
#      42         "Partitioning markdown files is only supported in unstructured>=0.4.16."
#      43     )
# ---> 45 return partition_md(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/documents/elements.py:518, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     516 @functools.wraps(func)
#     517 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 518     elements = func(*args, **kwargs)
#     519     sig = inspect.signature(func)
#     520     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/file_utils/filetype.py:591, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     589 @functools.wraps(func)
#     590 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 591     elements = func(*args, **kwargs)
#     592     sig = inspect.signature(func)
#     593     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/file_utils/filetype.py:546, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     544 @functools.wraps(func)
#     545 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 546     elements = func(*args, **kwargs)
#     547     sig = inspect.signature(func)
#     548     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/chunking/__init__.py:52, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      50 @functools.wraps(func)
#      51 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# ---> 52     elements = func(*args, **kwargs)
#      53     sig = inspect.signature(func)
#      54     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/partition/md.py:104, in partition_md(filename, file, text, url, include_page_breaks, include_metadata, parser, metadata_filename, metadata_last_modified, chunking_strategy, languages, detect_language_per_element, **kwargs)
#     100     text = response.text
#     102 html = markdown.markdown(text, extensions=["tables"])
# --> 104 return partition_html(
#     105     text=html,
#     106     include_page_breaks=include_page_breaks,
#     107     include_metadata=include_metadata,
#     108     parser=parser,
#     109     source_format="md",
#     110     metadata_filename=metadata_filename,
#     111     metadata_last_modified=metadata_last_modified or last_modification_date,
#     112     languages=languages,
#     113     detect_language_per_element=detect_language_per_element,
#     114     detection_origin=DETECTION_ORIGIN,
#     115 )
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/documents/elements.py:518, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     516 @functools.wraps(func)
#     517 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 518     elements = func(*args, **kwargs)
#     519     sig = inspect.signature(func)
#     520     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/file_utils/filetype.py:591, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     589 @functools.wraps(func)
#     590 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 591     elements = func(*args, **kwargs)
#     592     sig = inspect.signature(func)
#     593     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/file_utils/filetype.py:546, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     544 @functools.wraps(func)
#     545 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 546     elements = func(*args, **kwargs)
#     547     sig = inspect.signature(func)
#     548     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/chunking/__init__.py:52, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      50 @functools.wraps(func)
#      51 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# ---> 52     elements = func(*args, **kwargs)
#      53     sig = inspect.signature(func)
#      54     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/partition/html.py:139, in partition_html(filename, file, text, url, encoding, include_page_breaks, include_metadata, headers, ssl_verify, parser, source_format, html_assemble_articles, metadata_filename, metadata_last_modified, skip_headers_and_footers, chunking_strategy, languages, detect_language_per_element, detection_origin, **kwargs)
#     136 if skip_headers_and_footers:
#     137     document = filter_footer_and_header(document)
# --> 139 return list(
#     140     apply_lang_metadata(
#     141         document_to_element_list(
#     142             document,
#     143             sortable=False,
#     144             include_page_breaks=include_page_breaks,
#     145             last_modification_date=metadata_last_modified or last_modification_date,
#     146             source_format=source_format if source_format else None,
#     147             detection_origin=detection_origin,
#     148             **kwargs,
#     149         ),
#     150         languages=languages,
#     151         detect_language_per_element=detect_language_per_element,
#     152     ),
#     153 )
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/partition/lang.py:357, in apply_lang_metadata(elements, languages, detect_language_per_element)
#     354     elements = list(elements)
#     356 full_text = " ".join(e.text for e in elements if hasattr(e, "text"))
# --> 357 detected_languages = detect_languages(text=full_text, languages=languages)
#     358 if (
#     359     detected_languages is not None
#     360     and len(languages) == 1
#     361     and detect_language_per_element is False
#     362 ):
#     363     # -- apply detected language to each metadata --
#     364     for e in elements:
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/unstructured/partition/lang.py:306, in detect_languages(text, languages)
#     299     logger.warning(
#     300         f'Since "auto" is present in the input languages provided ({languages}), '
#     301         "the language will be auto detected and the rest of the inputted "
#     302         "languages will be ignored.",
#     303     )
#     305 try:
# --> 306     langdetect_result = detect_langs(text)
#     307 except lang_detect_exception.LangDetectException as e:
#     308     logger.warning(e)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langdetect/detector_factory.py:137, in detect_langs(text)
#     135 detector = _factory.create()
#     136 detector.append(text)
# --> 137 return detector.get_probabilities()
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langdetect/detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langdetect/detector.py:148, in Detector._detect_block(self)
#     146 def _detect_block(self):
#     147     self.cleaning_text()
# --> 148     ngrams = self._extract_ngrams()
#     149     if not ngrams:
#     150         raise LangDetectException(ErrorCode.CantDetectError, 'No features in text.')
#
# File ~/Documents/Projects/venv-Threat-Actor-RAG/lib64/python3.12/site-packages/langdetect/detector.py:198, in Detector._extract_ngrams(self)
#     196         w = ngram.grams[-n:]
#     197         if w and w != ' ' and w in self.word_lang_prob_map:
# --> 198             result.append(w)
#     199 return result
#
# KeyboardInterrupt:

# %%
# check content of doc page
print(md_docs[0].page_content)
# Out:
# Threat actor: Big Panda
#
# UUID: 4777aa1a-1bc4-4f81-8c1d-9c50c739d314
#
# First seen:
#
# Source last modified: 2020-04-19
#
# Threat actor aliases
#
# Big Panda (CrowdStrike)
#
# Description
#
# A threat actor mentioned in a summary report only, so we don't know who they are yet.
#
# Sponsor type and motivation
#
# Sponsor:
#
# Motivation:
#
# Country of origin
#
# China
#
# Observed attacked sectors where victims operate in
#
# Observed attacked countries where victims operate in
#
# Observed usage of tools
#
# Reported hacking operations
#
# Reported counter operations against threat actor

# %% [markdown]
# # Split documents
# Check token counts of documents.

# %%
# check number of tokens before we create chunks with OpenAI tokenizer, as we will use their LLM as well

tokenizer = tiktoken.encoding_for_model('gpt-3.5-turbo')

def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=() #To disable this check for all special tokens
    )
    return len(tokens)

# Get token counts
token_counts = [tiktoken_len(doc.page_content) for doc in md_docs]

print(f"""[+] Token Counts:
Min: {min(token_counts)}
Avg: {int(sum(token_counts) / len(token_counts))}
Max: {max(token_counts)}""")
# Out:
# [+] Token Counts:
# Min: 46
# Avg: 3041
# Max: 45237

# %% [markdown]
# # Chunk text
# Using Langchain text splitter.

# %%
print('[+] Initializing RecursiveCharacterTextSplitter..')
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,  # number of tokens overlap between chunks
    length_function=tiktoken_len,
    separators=['\n\n', '\n', ' ', '']
)
# Out:
# [+] Initializing RecursiveCharacterTextSplitter..

# %%
print('[+] Splitting documents in chunks..')
chunks = text_splitter.split_documents(md_docs)

print(f'[+] Number of documents: {len(md_docs)}')
print(f'[+] Number of chunks: {len(chunks)}')
# Out:
# [+] Splitting documents in chunks..
# [+] Number of documents: 2777
# [+] Number of chunks: 23207

# %% [markdown]
# # Contribute dataset to .jsonl file (optional)
# https://huggingface.co/datasets/TomTheAnalyst/ETDA-Threat-Actors

# %%
json_documents = []
m = hashlib.md5()
for doc in md_docs:
    doc_name = os.path.basename(doc.metadata['source'])
    m.update(doc_name.encode('utf-8'))
    uid = m.hexdigest()[:12]
    chunks_strings = text_splitter.split_text(doc.page_content)
    for i, chunk in enumerate(chunks_strings):
        # Add JSON object to array
        json_documents.append({
            'id': f'{uid}-{i}',
            'text': chunk,
            'source': doc_name
        })

# %%
print(f'[+] Exporting groups as .jsonl file..')
with open(f'{os.path.join(contrib_directory, "ETDA-threat-actors-index-reports.jsonl")}', 'w') as f:
    for doc in json_documents:
        f.write(json.dumps(doc) + '\n')
# Out:
# [+] Exporting groups as .jsonl file..

# %% [markdown]
# # Generate embeddings using open-source function

# %%
# create the open-source embedding function
embedding_function = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

# load it into Chroma and save it to disk
db = Chroma.from_documents(chunks, embedding_function, collection_name="groups_collection", persist_directory="./chroma_db")

# %% [markdown]
# # Testing query

# %%
# query it
query = "What vulnerabilities has Cl0p exploited?"
relevant_docs = db.similarity_search(query)

# print results
print(len(relevant_docs))
print(relevant_docs[0].page_content)
